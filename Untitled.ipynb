# %%
import pandas as pd
import numpy as np

# %%
def flatten(l):
    lnew = []
    for l0 in l:
        lnew+=l0
    return list(set(lnew))

# %%
def tovec(subset,basis):
    d = {b:0 for b in basis}
    for s in subset:
        d[s]+=1
    return [d[b] for b in basis]

# %%
recipesdf = pd.read_pickle('data/recmini.pk')
reviewsdf = pd.read_pickle('data/reviewsred.pk')

# %%
# Out:
#                                                        Name  \
# RecipeId
# 387                         Chocolate Coffee Ice Cream Soda
# 707                             Tricolor Crustless "Quiche"
# 721                                 Vidalia Onion Casserole
# 736                         Whole Grain Buttermilk Pancakes
# 742                                        Yolkless Noodles
# ...                                                     ...
# 78355                                    Garlic Basil Bread
# 80121     Cranberry Salad in Raspberry Jello with Cream ...
# 91931                                     Homemade Gel Pack
# 183593                                  Peanut Butter Oreos
# 282837                                       Vegan Parmesan
#
#                RecipeCategory  \
# RecipeId
# 387           Frozen Desserts
# 707               Savory Pies
# 721                 Vegetable
# 736                 Breakfast
# 742           Low Cholesterol
# ...                       ...
# 78355            Yeast Breads
# 80121                 Gelatin
# 91931     Homeopathy/Remedies
# 183593                Dessert
# 282837                  Vegan
#
#                                       RecipeIngredientParts TotalTime
# RecipeId
# 387       [chocolate flavored coffee, milk, coffee ice c...      PT0S
# 707       [spinach, carrots, potatoes, low-fat cream che...      PT0S
# 721       [butter, herb seasoned stuffing mix, butter, e...      PT0S
# 736       [whole wheat bread flour, cornmeal, light brow...      PT0S
# 742       [all-purpose flour, salt, water, olive oil, al...      PT0S
# ...                                                     ...       ...
# 78355     [basil, salt, sugar, flour, garlic, olive oil,...      PT0S
# 80121     [fresh cranberries, crushed pineapple, walnut ...      PT0S
# 91931                                               [water]      PT0S
# 183593                                      [peanut butter]      PT0S
# 282837                            [nutritional yeast, salt]      PT0S
#
# [1352 rows x 4 columns]

# %%
authors = list(set(reviewsdf['AuthorId'].values))
data_by_author = {a:{'ratings':[],'recids':[]} for a in authors}
for i in reviewsdf.index:
    ai = reviewsdf['AuthorId'][i]
    data_by_author[ai]['ratings'].append(reviewsdf['Rating'][i])
    data_by_author[ai]['recids'].append(reviewsdf['RecipeId'][i])
    
for a in authors:
    data_by_author[a]['No_ratings'] = len(data_by_author[a]['ratings'])
    data_by_author[a]['Mean_rating'] = np.mean(data_by_author[a]['ratings'])
    data_by_author[a]['Std_ratings'] = np.std(data_by_author[a]['ratings'])

reviewsdf['Auth_No_Ratings'] = [len(data_by_author[a]['ratings']) for a in reviewsdf['AuthorId'].values]
reviewsdf['Auth_Std_Ratings'] = [np.std(data_by_author[a]['ratings']) for a in reviewsdf['AuthorId'].values]
reviewsdf['Auth_Avg_Rating'] = [np.mean(data_by_author[a]['ratings']) for a in reviewsdf['AuthorId'].values]

# %%
def get_authors(min_rev,min_std):
    return [a for a in authors if data_by_author[a]['No_ratings'] >= min_rev and data_by_author[a]['Std_ratings'] > min_std]

# %%
author_subset = get_authors(50,0)

# %%
def summarize(authorlist):
    no_authors = len(authorlist)
    recids = []
    for a in authorlist:
        recids+=data_by_author[a]['recids']
    norevs = len(recids)
    norecs = len(set(recids))
    return {'Reviewers':no_authors,'Recipes':norecs,'Ratings':norevs,'Avg_no_by_rec':norevs/norecs}

# %%
summarize(author_subset)
# Out:
# {'Reviewers': 3382,
#  'Recipes': 221276,
#  'Ratings': 764847,
#  'Avg_no_by_rec': 3.4565294021945445}

# %%
summarize(get_authors(100,0))
# Out:
# {'Reviewers': 1724,
#  'Recipes': 208761,
#  'Ratings': 650005,
#  'Avg_no_by_rec': 3.1136323355416002}

# %% [markdown]
# # Similar Recipes by Name
#
# We will try to group together recipes with similar names.

# %% [markdown]
# To speed things up, we do the grouping within each recipe category first.

# %%
recipenames = list(recipesdf['Name'].values)
recipecategories = list(set(recipesdf['RecipeCategory'].values))

category_to_recnames = {c:[] for c in recipecategories}
category_to_recids = {c:[] for c in recipecategories}
for i in recipesdf.index:
    c = recipesdf['RecipeCategory'][i]
    n = recipesdf['Name'][i]
    category_to_recnames[c].append(n)
    category_to_recids[c].append(i)

# %% [markdown]
# We will use a sentence transformer to embed the recipe names as vectors and then cluster the names using the embedding.

# %%
from sentence_transformers import SentenceTransformer
embedder = SentenceTransformer("all-MiniLM-L6-v2")

from sklearn.cluster import KMeans, DBSCAN

def kmeans(sentences,k):
    clustering_model = KMeans(n_clusters = k)
    vecs = embedder.encode(sentences)
    clustering_model.fit(vecs)
    cluster_assignment = clustering_model.labels_
    clusters = {i:[] for i in range(max(cluster_assignment)+1)}
    for i in range(len(cluster_assignment)):
        clusters[cluster_assignment[i]].append(sentences[i])
    return clusters

def dbscan(sentences,ep,msam):
    clustering_model = DBSCAN(eps=ep, min_samples=msam, metric='euclidean')
    vecs = embedder.encode(sentences)
    clustering_model.fit(vecs)
    cluster_assignment = clustering_model.labels_
    clusters = {i:[] for i in range(-1,max(cluster_assignment)+1)}
    for i in range(len(cluster_assignment)):
        clusters[cluster_assignment[i]].append(sentences[i])
    return clusters

def dbscan_no(sentences,ep,msam):
    clustering_model = DBSCAN(eps=ep, min_samples=msam, metric='euclidean')
    vecs = embedder.encode(sentences)
    clustering_model.fit(vecs)
    cluster_assignment = clustering_model.labels_
    clusters = {i:[] for i in range(max(cluster_assignment)+1)}
    for i in range(len(cluster_assignment)):
        if cluster_assignment[i]>=0:
            clusters[cluster_assignment[i]].append(sentences[i])
    return clusters

def closest(words,target):
    vecs = embedder.encode([target]+words)
    wvs = vecs[1:]
    tv = vecs[0]
    w0 = words[0]
    d0 = np.linalg.norm(tv-wvs[0])
    for i in range(1,len(words)):
        vi = wvs[i]
        di = np.linalg.norm(tv-vi)
        if di < d0:
            d0 = di
            w0 = words[i]
    return w0

def closest_to_center(words):
    if len(words)==1:
        return words[0]
    vecs = embedder.encode(words)
    true_center = (1/len(vecs))*sum(vecs)
    w0 = words[0]
    d0 = np.linalg.norm(vecs[0]-true_center)
    for i in range(1,len(words)):
        di = np.linalg.norm(vecs[i]-true_center)
        if di < d0:
            w0 = words[i]
            d0 = di
    return w0

def dbscan_reorg(clusters):
    m =max(list(clusters.keys()))
    newclusters = {i:clusters[i] for i in range(m)}
    for x in clusters[-1]:
        newclusters[m] = [x]
        m+=1
    return newclusters
    
def relabel_clusters(clusters):
    return {closest_to_center(clusters[c]):clusters[c] for c in clusters}

def dbscan_nice(sentences,ep,msam):
    clus0 = dbscan(sentences,ep,msam)
    clus1 = dbscan_reorg(clus0)
    return relabel_clusters(clus1)

# %%
recipe_labels = {}

for c in category_to_recnames:
    rs = category_to_recnames[c]
    if len(rs)>2:
        clus = dbscan_nice(rs,0.4,2)
        for c in clus:
            if c in recipe_labels:
                recipe_labels[c]+=clus[c]
            else:
                recipe_labels[c] = clus[c]

# %%
recipe_labels_inv = {n:l for l in recipe_labels for n in recipe_labels[l]}

# %%
labelsdf = pd.read_pickle('data/recipelabels.pk')

# %%
rid_to_label = {r:'Not found' for r in recipesdf.index}
for r in labelsdf.index:
    rid_to_label[r] = labelsdf['Label'][r]
recipesdf['Label'] = [rid_to_label[r] for r in recipesdf.index]

# %%
recipes_w_labels = recipesdf.loc[recipesdf.Label != 'Not found']

# %%
recipes_w_labels
# Out:
#                                        Name RecipeCategory  \
# RecipeId
# 524289      Apple-Glazed Stuffed Pork Chops           Pork
# 40                            Best Lemonade      Beverages
# 42                             Cabbage Soup      Vegetable
# 47                     Butter Pecan Cookies        Dessert
# 48                         Boston Cream Pie            Pie
# ...                                     ...            ...
# 523058    Triple Chocolate Zucchini Muffins   Quick Breads
# 523104                    French Onion Soup      < 4 Hours
# 523120         Homemade Chicken & Rice Soup        Chicken
# 523582                   Garlic Cream Sauce         Sauces
# 523584             Green Chocolate Smoothie      Smoothies
#
#                                       RecipeIngredientParts TotalTime  \
# RecipeId
# 524289    [bacon, leeks, other dry white wine, thyme, sa...     PT40M
# 40        [sugar, lemon rind, lemon, zest of, fresh wate...     PT35M
# 42        [plain tomato juice, cabbage, onion, carrots, ...     PT50M
# 47        [butter, light brown sugar, granulated sugar, ...    PT1H4M
# 48        [margarine, cake flour, baking powder, salt, s...   PT2H15M
# ...                                                     ...       ...
# 523058    [whole wheat bread flour, fine rolled oats, ba...     PT55M
# 523104    [sweet unsalted butter, yellow onions, minced ...   PT3H50M
# 523120    [boneless skinless chicken breast half, onion,...     PT50M
# 523582    [butter, minced  fresh garlic cloves, flour, h...     PT15M
# 523584    [fresh spinach, avocado, cinnamon, honey, liqu...     PT15M
#
#           NoIngredients                         Label
# RecipeId
# 524289                8       Apple Glazed Pork Chops
# 40                    5             The Best Lemonade
# 42                    5                  Cabbage Soup
# 47                    6          Butter Pecan Cookies
# 48                   16              Boston Cream Pie
# ...                 ...                           ...
# 523058               14              Zucchini Muffins
# 523104               14             French Onion Soup
# 523120                9  Creamy Chicken and Rice Soup
# 523582                6                  Garlic Sauce
# 523584                5    Strawberry Banana Smoothie
#
# [44619 rows x 6 columns]

# %%
ingredients_to_recipes = {i:[] for i in ingredients}
for r in recipesdf.index:
    ris = recipesdf['RecipeIngredientParts'][r]
    for i in ris:
        ingredients_to_recipes[i].append(r)

# %%
labels = list(set(labelsdf['Label'].values))

# %%
ingredientwords = flatten([l.split(' ') for l in ingredients])

# %%
labels_to_ingredients = {l:[] for l in labels}
for r in recipes_w_labels.index:
    labels_to_ingredients[recipes_w_labels['Label'][r]].append(recipes_w_labels['RecipeIngredientParts'][r])

# %%
len([l for l in labels if len(labels_to_ingredients[l])>1])
# Out:
# 6028

# %%
# Out:
# {'Black Magic Cake': [['flour',
#    'sugar',
#    'baking soda',
#    'baking powder',
#    'salt',
#    'eggs',
#    'coffee',
#    'buttermilk',
#    'pure vanilla extract',
#    'butter',
#    'regular margarine',
#    'vanilla',
#    'lemon juice',
#    'egg',
#    'walnuts',
#    "confectioners' sugar"],
#   ['all-purpose flour',
#    'white sugar',
#    'baking soda',
#    'baking powder',
#    'salt',
#    'coffee',
#    'buttermilk',
#    'pure vanilla extract'],
#   ['butter',
#    'margarine',
#    'sugar',
#    'buttermilk',
#    'pure vanilla extract',
#    'eggs',
#    'all-purpose flour',
#    'salt',
#    'baking soda'],
#   ['flour',
#    'sugar',
#    'baking soda',
#    'baking powder',
#    'salt',
#    'eggs',
#    'buttermilk',
#    'vanilla'],
#   ['flour',
#    'sugar',
#    'baking soda',
#    'baking powder',
#    'salt',
#    'eggs',
#    'brewed coffee',
#    'buttermilk',
#    'vanilla',
#    'butter',
#    'powdered sugar',
#    'milk',
#    'salt',
#    'vanilla'],
#   ['all-purpose flour',
#    'white sugar',
#    'baking powder',
#    'baking soda',
#    'salt',
#    'other shortening',
#    'water',
#    'brewed coffee',
#    'vanilla',
#    'eggs'],
#   ['sugar', 'water', 'heavy cream']],
#  'Brunch Casserole': [['Croutons',
#    'cheddar cheese',
#    'eggs',
#    'milk',
#    'prepared mustard',
#    'pepper',
#    'bacon'],
#   ['breakfast sausage',
#    'potatoes',
#    'butter',
#    'mild cheddar cheese',
#    'onion',
#    'green chili',
#    'small curd cottage cheese',
#    'eggs'],
#   ['English muffin',
#    'cheese',
#    'smoked salmon',
#    'eggs',
#    'milk',
#    'mustard powder',
#    'onions',
#    'spring onions',
#    'baby asparagus',
#    'salt',
#    'pepper',
#    'paprika'],
#   ['reduced-fat sharp cheddar cheese',
#    'eggs',
#    'milk',
#    'salt',
#    'dry mustard',
#    'cracked pepper',
#    'shrimp',
#    'butter'],
#   ['butter',
#    'butter',
#    'swiss cheese',
#    'low-fat monterey jack cheese',
#    'bacon',
#    'eggs',
#    'milk',
#    'white wine',
#    'green onion',
#    'dijon-style mustard',
#    'ground white pepper',
#    'fresh cayenne pepper',
#    'sour cream',
#    'fresh parmesan cheese'],
#   ['bulk sausage',
#    'reduced-fat sharp cheddar cheese',
#    'eggs',
#    'milk',
#    'salt',
#    'pepper'],
#   ['cheddar cheese',
#    'eggs',
#    'milk',
#    'dry mustard',
#    'salt',
#    'cayenne',
#    'onion powder',
#    'bacon',
#    'chopped tomato'],
#   ['butter',
#    'cooked ham',
#    'cheddar cheese',
#    'eggs',
#    'milk',
#    'salt',
#    'pepper']],
#  'Chicken Soup': [['raw chicken',
#    'fresh tarragon',
#    'lemon, zest of',
#    'pepper',
#    'butter',
#    'plain flour',
#    'milk',
#    'watercress'],
#   ['chicken meat',
#    'butter',
#    'margarine',
#    'onion',
#    'celery',
#    'green chili',
#    'garlic',
#    'chicken broth',
#    'chicken bouillon cubes',
#    'thyme',
#    'pepper',
#    'potato',
#    'carrot'],
#   ['potatoes',
#    'carrots',
#    'frozen spinach',
#    'kale',
#    'onions',
#    'frozen green peas',
#    'chicken legs',
#    'water',
#    'chicken bouillon cubes'],
#   ['boneless skinless chicken breast half',
#    'olive oil',
#    'onion',
#    'celery rib',
#    'carrots',
#    'garlic',
#    'low sodium chicken broth',
#    'diced tomatoes',
#    'no-salt-added tomato sauce'],
#   ['elbow macaroni',
#    'canned chicken broth',
#    'tomatoes',
#    'carrots',
#    'onions',
#    'zucchini',
#    'garlic',
#    'chicken',
#    'fresh basil leaf',
#    'kosher salt',
#    'fresh ground black pepper',
#    'olive oil',
#    'fresh parmesan cheese'],
#   ['chicken wings',
#    'onion',
#    'celery',
#    'carrots',
#    'turnip',
#    'parsnips',
#    'fresh dill',
#    'fresh parsley',
#    'kosher salt',
#    'fresh ground pepper'],
#   ['chicken broth',
#    'water',
#    'potatoes',
#    'boneless skinless chicken breast half',
#    'carrot',
#    'celery',
#    'diced tomatoes',
#    'green onion',
#    'fresh parsley',
#    'dried thyme leaves'],
#   ['roasting chicken',
#    'onion',
#    'celery',
#    'carrot',
#    'salt',
#    'pepper',
#    'fresh dill',
#    'Italian parsley',
#    'stewed tomatoes'],
#   ['chicken breasts',
#    'carrots',
#    'celery',
#    'celery leaves',
#    'onion',
#    'parsley',
#    'thyme',
#    'dry mustard',
#    'chicken bouillon granules',
#    'pepper'],
#   ['roasting chicken',
#    'carrots',
#    'celery ribs',
#    'chicken bouillon',
#    'onion',
#    'couscous',
#    'garlic powder'],
#   ['dried great northern beans',
#    'water',
#    'onion',
#    'fennel bulbs',
#    'carrots',
#    'minced  fresh garlic cloves',
#    'fresh parsley',
#    'dried rosemary',
#    'pepper',
#    'chicken broth',
#    'diced tomatoes'],
#   ['olive oil',
#    'onion',
#    'broth',
#    'minced  fresh garlic cloves',
#    'thyme',
#    'pepper',
#    'parsley',
#    'carrots',
#    'elbow macaroni',
#    'zucchini',
#    'tomatoes'],
#   ['olive oil',
#    'leeks',
#    'minced  fresh garlic cloves',
#    'carrot',
#    'celery',
#    'zucchini',
#    'swede',
#    'pumpkin',
#    'peas',
#    'frozen whole kernel corn',
#    'water',
#    'bay leaves'],
#   ['chicken broth',
#    'rice',
#    'carrots',
#    'celery',
#    'zucchini',
#    'butter',
#    'margarine',
#    'flour',
#    'milk',
#    'half-and-half',
#    'green onion',
#    'parsley'],
#   ['roasting chicken',
#    'carrots',
#    'celery ribs',
#    'parsnips',
#    'onion',
#    'dill sprigs',
#    'cold water',
#    'celery ribs'],
#   ['butter',
#    'onion',
#    'chili powder',
#    'baking potato',
#    'chicken broth',
#    'frozen whole kernel corn',
#    'chicken meat',
#    'frozen green beans',
#    'sour cream'],
#   ['chicken broth',
#    'frozen corn',
#    'celery rib',
#    'carrot',
#    'onion',
#    'diced tomatoes'],
#   ['chicken thighs',
#    'carrot',
#    'minced  fresh garlic cloves',
#    'onion',
#    'potatoes',
#    'celery',
#    'fat-free chicken broth',
#    'sea salt'],
#   ['chicken broth',
#    'Rotel Tomatoes',
#    'onion',
#    'bay leaf',
#    'salt',
#    'pepper',
#    'dried chives',
#    'dried oregano',
#    'dried leaf basil',
#    'chicken breasts',
#    'carrots',
#    'celery rib',
#    'green onion'],
#   ['chicken breasts', 'chicken broth', 'carrots', 'celery', 'garlic'],
#   ['water', 'chicken', 'carrots', 'celery', 'sweet brown rice', 'salt'],
#   ['chicken',
#    'onion',
#    'celery',
#    'minced  fresh garlic cloves',
#    'carrots',
#    'bay leaf',
#    'peppercorn',
#    'butter',
#    'onion',
#    'celery',
#    'minced  fresh garlic cloves',
#    'bay leaves',
#    'salt',
#    'pepper',
#    'carrots',
#    'potatoes'],
#   ['chicken',
#    'celery',
#    'carrot',
#    'sweet bell pepper',
#    'thyme',
#    'fresh cayenne pepper',
#    'basil',
#    'bay leaf',
#    'water',
#    'chicken bouillon',
#    'orzo pasta'],
#   ['onion',
#    'turnip',
#    'swede',
#    'carrots',
#    'parsnips',
#    'celery',
#    'parsley',
#    'small shell pasta',
#    'salt',
#    'pepper',
#    'white Worcestershire sauce'],
#   ['corn',
#    'carrots',
#    'French style green beans',
#    'water',
#    'bouillon cube',
#    'onion powder',
#    'garlic powder',
#    'potato']],
#  'Crispy Lemon Cookies': [['flour',
#    'baking soda',
#    'salt',
#    'other shortening',
#    'sugar',
#    'lemon pudding mix',
#    'eggs'],
#   ['butter',
#    'sugar',
#    'egg',
#    'lemon, zest of',
#    'fresh lemon juice',
#    'vanilla',
#    'baking powder',
#    'baking soda',
#    'salt',
#    'flour'],
#   ['sweet unsalted butter',
#    'other shortening',
#    'sugar',
#    'egg',
#    'milk',
#    'pure vanilla extract',
#    'all-purpose flour',
#    'salt',
#    'lemon rind',
#    'lemon, zest of',
#    'baking soda',
#    'sugar'],
#   ['lemon juice',
#    'lemon rind',
#    'sweet unsalted butter',
#    'all-purpose flour',
#    'baking powder',
#    'salt',
#    'powdered sugar',
#    'egg',
#    'pure vanilla extract']],
#  'Spaghetti With Meat Sauce': [['tomato with juice',
#    'water',
#    'tomato paste',
#    'minced  fresh garlic cloves',
#    'bay leaves',
#    'clove',
#    'allspice',
#    'ginger',
#    'cinnamon',
#    'onion'],
#   ['ground beef',
#    'onion',
#    'tomato sauce',
#    'tomato paste',
#    'water',
#    'bay leaves',
#    'parsley flakes',
#    'oregano',
#    'minced  fresh garlic cloves',
#    'sugar',
#    'fresh parmesan cheese',
#    'romano cheese',
#    'spaghetti noodles'],
#   ['ground turkey',
#    'tomatoes',
#    'green chili',
#    'onion',
#    'minced  fresh garlic cloves',
#    'dried oregano',
#    'black pepper'],
#   ['lean ground beef', 'green chili', 'onion', 'fresh parmesan cheese'],
#   ['diced tomatoes',
#    'tomato sauce',
#    'onion',
#    'minced  fresh garlic cloves',
#    'spaghetti noodles',
#    'olive oil'],
#   ['tomato paste', 'ground beef', 'onion', 'spaghetti', 'salt', 'pepper']],
#  'Flour Tortillas': [['flour', 'water', 'salt', 'other shortening'],
#   ['flour', 'salt', 'baking powder', 'water'],
#   ['all-purpose flour', 'vegetable shortening', 'salt', 'tap water'],
#   ['all-purpose flour', 'other shortening', 'salt', 'warm water'],
#   ['all-purpose flour', 'salt', 'other shortening', 'water'],
#   ['all-purpose flour',
#    'baking powder',
#    'vegetable shortening',
#    'water',
#    'salt'],
#   ['flour', 'salt', 'baking powder', 'other shortening', 'warm water'],
#   ['all-purpose flour', 'salt', 'other shortening', 'water'],
#   ['unbleached flour',
#    'unbleached flour',
#    'table salt',
#    'baking powder',
#    'vegetable shortening',
#    'warm water'],
#   ['bread flour',
#    'other shortening',
#    'coconut oil',
#    'warm water',
#    'salt',
#    'honey'],
#   ['all-purpose flour',
#    'baking powder',
#    'salt',
#    'vegetable shortening',
#    'tap water'],
#   ['flour', 'baking powder', 'salt', 'warm water'],
#   ['flour', 'salt', 'baking powder', 'other shortening', 'warm water']],
#  'Tabbouleh': [['fresh parsley',
#    'of fresh mint',
#    'cucumbers',
#    'tomatoes',
#    'bulgur',
#    'onion',
#    'lemon juice',
#    'olive oil',
#    'salt',
#    'garlic'],
#   ['bulgur',
#    'parsley',
#    'tomatoes',
#    'onion',
#    'English cucumbers',
#    'red sweet bell pepper',
#    'green onion',
#    'minced  fresh garlic cloves',
#    'extra virgin olive oil',
#    'boiling water'],
#   ['bulgur',
#    'hot water',
#    'onion',
#    'parsley',
#    'tomatoes',
#    'of fresh mint',
#    'fresh lemon juice',
#    'olive oil',
#    'salt',
#    'pepper',
#    'iceberg lettuce'],
#   ['water',
#    'Bulgar wheat',
#    'tomatoes',
#    'flat leaf parsley',
#    'fresh lemon juice',
#    'red onions',
#    'scallion',
#    'garlic',
#    'olive oil',
#    'salt',
#    'fresh ground pepper'],
#   ['Bulgar wheat',
#    'boiling water',
#    'parsley',
#    'spring onions',
#    'mint',
#    'olive oil',
#    'lime juice',
#    'salt',
#    'black pepper',
#    'firm ripe tomatoes'],
#   ['bulgur wheat',
#    'cucumbers',
#    'tomatoes',
#    'spring onions',
#    'flat leaf parsley',
#    'of fresh mint',
#    'limes, juice of'],
#   ['parsley',
#    'English seedless cucumber',
#    'tomatoes',
#    'green onion',
#    'bulgur',
#    'pine nuts',
#    'olive oil',
#    'lemon',
#    'sugar'],
#   ['fresh parsley',
#    'tomatoes',
#    'red onions',
#    'bulgur',
#    'fresh lemon juice',
#    'olive oil',
#    'minced  fresh garlic cloves',
#    'salt',
#    'pepper'],
#   ['tomatoes', 'flat leaf parsley', 'bulgur', 'olive oil', 'salt'],
#   ['bulgur',
#    'fresh parsley',
#    'tomatoes',
#    'fresh mint leaves',
#    'onion',
#    'lemon juice',
#    'salt',
#    'extra virgin olive oil',
#    'leaf lettuce',
#    'cabbage leaf'],
#   ['Bulgar wheat',
#    'water',
#    'parsley',
#    'of fresh mint',
#    'scallion',
#    'tomatoes',
#    'cucumbers',
#    'green chili',
#    'iceberg lettuce',
#    'salt',
#    'lemon juice',
#    'olive oil'],
#   ['flat leaf parsley',
#    'spring onions',
#    'bulgur',
#    'firm ripe tomatoes',
#    'of fresh mint',
#    'salt',
#    'extra virgin olive oil',
#    'grape leaves',
#    'cabbage leaf'],
#   ['fresh parsley',
#    'spring onions',
#    'tomatoes',
#    'of fresh mint',
#    'onion',
#    'lemon juice',
#    'extra virgin olive oil',
#    'chili powder'],
#   ['boiling water',
#    'Bulgar wheat',
#    'fresh lemon juice',
#    'olive oil',
#    'kosher salt',
#    'kosher salt',
#    'fresh ground black pepper',
#    'scallion',
#    'fresh mint leaves',
#    'flat leaf parsley',
#    'cucumbers',
#    'grape tomatoes']],
#  'Cheesy Chicken Quesadillas': [['boneless skinless chicken breast half',
#    'chunky salsa',
#    '10-inch flour tortillas'],
#   ['chicken breast',
#    'water',
#    'cilantro',
#    'Flour Tortillas',
#    'corn tortillas',
#    'sour cream',
#    'Salsa'],
#   ['spring onions',
#    'shallot',
#    'minced  fresh garlic cloves',
#    'chicken breast fillets',
#    'fresh coriander',
#    'limes, juice of',
#    'Flour Tortillas',
#    'lime wedge'],
#   ['jalapeno jack cheese', 'Flour Tortillas', 'butter', 'margarine'],
#   ['boneless skinless chicken breast half',
#    'minced  fresh garlic cloves',
#    'water',
#    'Flour Tortillas',
#    'cheddar cheese',
#    'low-fat monterey jack cheese'],
#   ['cheddar cheese', 'chicken', 'Salsa', 'tortilla']],
#  'Blueberry Dessert': [['Bisquick baking mix',
#    'sugar',
#    'butter',
#    'margarine',
#    'eggs',
#    'frozen blueberries',
#    'Bisquick baking mix',
#    'sugar',
#    'firm butter',
#    'margarine'],
#   ['blueberries',
#    'cinnamon',
#    'sugar',
#    'margarine',
#    'flour',
#    'baking powder',
#    'salt',
#    'milk',
#    'sugar',
#    'cornstarch',
#    'boiling water'],
#   ['all-purpose flour',
#    'margarine',
#    'cream cheese',
#    "confectioners' sugar",
#    'Cool Whip'],
#   ['sugar',
#    'margarine',
#    'lemon juice',
#    'cornstarch',
#    'salt',
#    'water',
#    'fresh blueberries'],
#   ['low fat graham cracker crumbs',
#    'butter',
#    'skim milk',
#    'vanilla',
#    'fat-free sugar-free instant vanilla pudding mix',
#    'frozen blueberries',
#    'Splenda granular',
#    'cornstarch',
#    'water',
#    'cinnamon'],
#   ['pecans', 'butter']],
#  'Mushroom Omelette': [['eggs',
#    'milk',
#    'mushrooms',
#    'onion',
#    'fresh parsley',
#    'coriander leaves',
#    'green chili',
#    'salt',
#    'black pepper',
#    'butter',
#    'margarine'],
#   ['eggs',
#    'dried leaf basil',
#    'dried oregano',
#    'low-fat ricotta cheese',
#    'tomatoes',
#    'onion',
#    'mushrooms'],
#   ['mushrooms',
#    'sweet unsalted butter',
#    'minced  fresh garlic cloves',
#    'sea salt',
#    'black pepper',
#    'parsley',
#    'eggs'],
#   ['mushrooms',
#    'onion',
#    'olive oil',
#    'butter',
#    'garlic powder',
#    'black pepper',
#    'salt',
#    'parsley',
#    'dried chives',
#    'eggs',
#    'butter',
#    'cheddar cheese',
#    'green chili'],
#   ['eggs',
#    'button mushroom',
#    'onions',
#    'salt',
#    'white pepper',
#    'butter',
#    'mustard powder']],
#  'Yellow Squash Patties': [['all-purpose flour',
#    'sugar',
#    'salt',
#    'milk',
#    'egg',
#    'onion',
#    'cheddar cheese',
#    'crushed red pepper flakes'],
#   ['onion',
#    'egg',
#    'seasoning salt',
#    'sugar',
#    'salt',
#    'pepper',
#    'self rising flour'],
#   ['onion',
#    'salt',
#    'self rising flour',
#    'cornmeal',
#    'egg',
#    'cheddar cheese',
#    'black pepper']],
#  'Pumpkin Angel Food Cake': [['pumpkin', 'water', 'Cool Whip'],
#   ['flour',
#    'sugar',
#    'ground cinnamon',
#    'ground nutmeg',
#    'cream of tartar',
#    'vanilla',
#    'salt',
#    'canned pumpkin',
#    "confectioners' sugar"],
#   ['canned pumpkin',
#    'pure vanilla extract',
#    'ground cinnamon',
#    'ground nutmeg',
#    'ground cloves',
#    'ground ginger'],
#   ['canned pumpkin',
#    'pure vanilla extract',
#    'cinnamon',
#    'nutmeg',
#    'clove',
#    'ginger']],
#  'Honey Soy Chicken Wings': [['scallion',
#    'soya sauce',
#    'Hoisin Sauce Recipe',
#    'honey',
#    'fresh ginger',
#    'white vinegar',
#    'dijon-style mustard',
#    'fresh cayenne pepper',
#    'garlic',
#    'chicken wings'],
#   ['chicken wings', 'honey', 'ketchup', 'soya sauce', 'garlic'],
#   ['chicken wings',
#    'soya sauce',
#    'minced  fresh garlic cloves',
#    'red wine',
#    'olive oil',
#    'honey'],
#   ['chicken wings',
#    'minced  fresh garlic cloves',
#    'ginger',
#    'soya sauce',
#    'honey',
#    'Ketjap Manis']],
#  'Lasagna Casserole': [['small shell pasta',
#    'lean ground beef',
#    'onion',
#    'tomato sauce',
#    'garlic powder',
#    'sour cream',
#    'low-fat monterey jack cheese'],
#   ['mozzarella cheese', 'cottage cheese', 'hamburger'],
#   ['ground beef',
#    'onion',
#    'tomato sauce',
#    'garlic powder',
#    'salt',
#    'cream cheese',
#    'evaporated milk',
#    'mozzarella cheese'],
#   ['ground turkey',
#    'ground beef',
#    'small curd cottage cheese',
#    'fresh parmesan cheese',
#    'mozzarella cheese',
#    'garlic powder'],
#   ['lean ground beef',
#    'onion',
#    'tomato sauce',
#    'oregano',
#    'pepper',
#    'pre-shredded mozzarella cheese']],
#  'Chewy Ginger Cookies': [['all-purpose flour',
#    'all-purpose flour',
#    'ground ginger',
#    'ground cinnamon',
#    'ground cloves',
#    'ground nutmeg',
#    'cocoa powder',
#    'sweet unsalted butter',
#    'ginger',
#    'light brown sugar',
#    'unsulphured molasses',
#    'baking soda',
#    'boiling water',
#    'granulated sugar'],
#   ['sugar',
#    'Sweetened Condensed Milk',
#    'molasses',
#    'eggs',
#    'all-purpose flour',
#    'ground ginger',
#    'baking powder',
#    'salt',
#    'cinnamon',
#    'crystallized ginger'],
#   ['all-purpose flour',
#    'all-purpose flour',
#    'ground ginger',
#    'ground cinnamon',
#    'ground cloves',
#    'ground nutmeg',
#    'cocoa powder',
#    'sweet unsalted butter',
#    'fresh ginger',
#    'light brown sugar',
#    'unsulphured molasses',
#    'baking soda',
#    'granulated sugar'],
#   ['flour',
#    'ginger powder',
#    'cinnamon',
#    'ground cloves',
#    'baking soda',
#    'salt',
#    'fresh cayenne pepper',
#    'light brown sugar',
#    'other shortening',
#    'butter',
#    'egg',
#    'molasses',
#    'crystallized ginger',
#    'fresh ginger',
#    'white sugar',
#    'powdered sugar'],
#   ['unbleached flour',
#    'baking soda',
#    'salt',
#    'ground cinnamon',
#    'ground ginger',
#    'clove',
#    'sweet unsalted butter',
#    'light brown sugar',
#    'egg',
#    'molasses',
#    'granulated sugar'],
#   ['butter',
#    'white sugar',
#    'eggs',
#    'molasses',
#    'baking soda',
#    'cinnamon',
#    'ground ginger',
#    'flour',
#    'crystallized ginger']],
#  'Cranberry Pancakes': [['milk',
#    'butter',
#    'egg',
#    'flour',
#    'baking powder',
#    'sugar',
#    'sugar',
#    'salt',
#    'fresh cranberries',
#    'frozen cranberries'],
#   ['water',
#    'sugar',
#    'dried cranberries',
#    'cornstarch',
#    'whole wheat bread flour',
#    'all-purpose flour',
#    'turbinado sugar',
#    'light brown sugar',
#    'baking powder',
#    'salt',
#    'dried cranberries',
#    'cinnamon',
#    'ground ginger',
#    'fat-free evaporated milk',
#    'skim milk',
#    'egg substitute',
#    'vanilla'],
#   ['fresh cranberries',
#    'all-purpose flour',
#    'whole wheat bread flour',
#    'whole wheat bread flour',
#    'yellow cornmeal',
#    'sugar',
#    'baking powder',
#    'salt',
#    'ground nutmeg',
#    'pure vanilla extract',
#    'nonfat milk',
#    'egg substitute',
#    'walnut oil',
#    'canola oil']],
#  '5 Hour Beef Stew': [['stewing beef',
#    'minute tapioca',
#    'light brown sugar',
#    'celery',
#    'carrot',
#    'peas',
#    'salt',
#    'potatoes',
#    'Accent seasoning',
#    'onion',
#    'tomato with juice',
#    'tomatoes'],
#   ['onion',
#    'carrots',
#    'celery',
#    'potatoes',
#    'sugar',
#    'salt',
#    'dry tapioca',
#    'DelMonte ketchup'],
#   ['carrots',
#    'celery',
#    'potatoes',
#    'green chili',
#    'onion',
#    'tomatoes',
#    'water',
#    'sugar',
#    'pearl tapioca'],
#   ['onion',
#    'carrots',
#    'potatoes',
#    'celery',
#    'green chili',
#    'tapioca',
#    'salt',
#    'pepper',
#    'water'],
#   ['potatoes',
#    'onions',
#    'carrots',
#    'minced  fresh garlic cloves',
#    'tapioca',
#    'white Worcestershire sauce',
#    'sugar',
#    'salt',
#    'pepper',
#    'water'],
#   ['garlic',
#    'onion',
#    'celery',
#    'olive oil',
#    'beef top round steak',
#    'tomato paste',
#    'fresh thyme',
#    'dried thyme leaves',
#    'bay leaf',
#    'fresh parsley',
#    'red wine',
#    'carrots',
#    'baby red potato',
#    'potato starch',
#    'cornstarch'],
#   ['peas',
#    'mushrooms',
#    'celery',
#    'carrots',
#    'potatoes',
#    'onion',
#    'Burgundy wine',
#    'salt',
#    'pepper',
#    'ground white pepper']],
#  "Simple and Delicious Mac 'n' Cheese": [['broccoli florets',
#    'onion',
#    'minced  fresh garlic cloves',
#    'butter',
#    'butter',
#    'milk',
#    'cooked ham',
#    'dijon-style mustard',
#    'fresh parmesan cheese'],
#   ['elbow macaroni',
#    'fresh parmesan cheese',
#    'milk',
#    'salt',
#    'butter',
#    'paprika'],
#   ['cavatappi pasta',
#    'reduced-fat sharp cheddar cheese',
#    'fresh parmesan cheese',
#    'milk',
#    'flour',
#    'butter',
#    'pepper']],
#  'Easy Corn Fritters': [['flour',
#    'baking powder',
#    'salt',
#    'egg',
#    'powdered sugar'],
#   ['flour', 'milk', 'baking powder', 'eggs', 'salt'],
#   ['corn',
#    'egg',
#    'sugar',
#    'salt',
#    'butter',
#    'baking powder',
#    'flour',
#    'milk',
#    'canola oil'],
#   ['corn',
#    'eggs',
#    'salt',
#    'flour',
#    'baking powder',
#    'sugar',
#    'bacon grease',
#    'margarine']],
#  'Italian Soda': [['half-and-half', 'milk', 'non-flavored soda water'],
#   ['carbonated water', 'plain soymilk'],
#   ['sparkling water', 'half-and-half'],
#   ['sparkling water', 'milk']],
#  'Italian Bean Salad': [['dry white beans',
#    'yellow onions',
#    'minced  fresh garlic cloves',
#    'water',
#    'bay leaf',
#    'salt',
#    'minced  fresh garlic cloves',
#    'red wine vinegar',
#    'red onions',
#    'lemon juice',
#    'dijon-style mustard',
#    'red sweet bell pepper',
#    'fresh basil leaf',
#    'parsley',
#    'fresh sage',
#    'black pepper'],
#   ['cannellini beans',
#    'shallots',
#    'lemon juice',
#    'lemon yogurt',
#    'fresh parsley',
#    'dijon-style mustard',
#    'olive oil',
#    'salt',
#    'tarragon',
#    'black pepper'],
#   ['white beans',
#    'red onions',
#    'celery',
#    'scallion',
#    'parsley',
#    'olive oil',
#    'fresh ground pepper'],
#   ['spring onions',
#    'minced  fresh garlic cloves',
#    'red chile',
#    'cannellini beans',
#    'butter beans',
#    'olive oil',
#    'white wine vinegar',
#    'flat leaf parsley']],
#  'Chicken and Spinach Curry': [['boneless skinless chicken breast half',
#    'onion',
#    'minced  fresh garlic cloves',
#    'ground ginger',
#    'ground cumin',
#    'turmeric',
#    'ground coriander',
#    'garam masala',
#    'tomatoes',
#    'salt',
#    'fresh ground black pepper',
#    'spinach'],
#   ['chicken',
#    'turmeric',
#    'ground fennel',
#    'ground coriander',
#    'chili powder',
#    'onions',
#    'fresh ginger',
#    'minced  fresh garlic cloves',
#    'salt',
#    'water',
#    'butter',
#    'minced  fresh garlic cloves',
#    'curry leaves',
#    'cumin seed',
#    'fennel seeds',
#    'fresh spinach',
#    'frozen chopped spinach',
#    'plain yogurt',
#    'garam masala'],
#   ['spinach', 'onion', 'curry paste', 'potato', 'salt', 'lime juice']],
#  'Pumpkin Bread': [['all-purpose flour',
#    'baking soda',
#    'baking powder',
#    'cinnamon',
#    'sugar',
#    'light brown sugar',
#    'eggs',
#    'black walnut extract',
#    'canned solid-pack pumpkin',
#    'walnut pieces'],
#   ['flour', 'baking soda', 'salt', 'cinnamon', 'sugar', 'pumpkin', 'eggs'],
#   ['other shortening',
#    'sugar',
#    'orange',
#    'water',
#    'eggs',
#    'pumpkin',
#    'flour',
#    'baking soda',
#    'salt',
#    'cinnamon',
#    'clove',
#    'baking powder',
#    'pecans',
#    'dates'],
#   ['eggs',
#    'water',
#    'pumpkin',
#    'flour',
#    'sugar',
#    'baking soda',
#    'salt',
#    'cinnamon'],
#   ['white sugar',
#    'fresh pumpkin puree',
#    'water',
#    'eggs',
#    'all-purpose flour',
#    'ground cinnamon',
#    'ground nutmeg',
#    'baking soda',
#    'salt',
#    'walnuts'],
#   ['flour',
#    'sugar',
#    'baking soda',
#    'salt',
#    'cinnamon',
#    'pumpkin',
#    'water',
#    'eggs',
#    'walnuts'],
#   ['walnuts',
#    'hazelnuts',
#    'flour',
#    'baking powder',
#    'cinnamon',
#    'nutmeg',
#    'baking soda',
#    'salt',
#    'butter',
#    'sugar',
#    'light brown sugar',
#    'vanilla',
#    'eggs',
#    'pumpkin',
#    'milk',
#    'maple syrup'],
#   ['other shortening',
#    'sugar',
#    'eggs',
#    'all-purpose flour',
#    'baking soda',
#    'baking powder',
#    'salt',
#    'ground cinnamon',
#    'ground cloves',
#    'pumpkin',
#    'water',
#    'raisins'],
#   ['eggs',
#    'sugar',
#    'water',
#    'pumpkin',
#    'flour',
#    'baking soda',
#    'baking powder',
#    'salt',
#    'cinnamon',
#    'nutmeg',
#    'Holiday Pumpkin Pie Spice'],
#   ['sugar',
#    'eggs',
#    'pumpkin',
#    'flour',
#    'baking soda',
#    'nutmeg',
#    'clove',
#    'cinnamon',
#    'allspice',
#    'baking powder',
#    'salt',
#    'water',
#    'raisins'],
#   ['canned pumpkin',
#    'egg',
#    'non-fat powdered milk',
#    'flour',
#    'Holiday Pumpkin Pie Spice',
#    'baking soda',
#    'pure vanilla extract',
#    'water',
#    'sugar substitute'],
#   ['other shortening',
#    'sugar',
#    'salt',
#    'baking soda',
#    'navel oranges',
#    'cinnamon',
#    'water',
#    'ground cloves',
#    'eggs',
#    'baking powder',
#    'pumpkin',
#    'flour',
#    'raisins'],
#   ['self rising flour',
#    'sugar',
#    'eggs',
#    'pumpkin',
#    'Holiday Pumpkin Pie Spice',
#    'cinnamon'],
#   ['all-purpose flour',
#    'cinnamon',
#    'baking soda',
#    'baking powder',
#    'salt',
#    'sugar',
#    'eggs',
#    'pure vanilla extract',
#    'fresh pumpkin'],
#   ['flour',
#    'sugar',
#    'baking soda',
#    'salt',
#    'cinnamon',
#    'nutmeg',
#    'water',
#    'eggs',
#    'vanilla',
#    'pumpkin'],
#   ['flour',
#    'sugar',
#    'pumpkin',
#    'cinnamon',
#    'salt',
#    'ground cloves',
#    'baking soda',
#    'milk',
#    'egg'],
#   ['pumpkin',
#    'fresh pumpkin puree',
#    'dry yeast',
#    'honey',
#    'unbleached flour',
#    'salt',
#    'milk',
#    'salt'],
#   ['flour',
#    'sugar',
#    'baking soda',
#    'salt',
#    'cinnamon',
#    'nutmeg',
#    'eggs',
#    'water',
#    'canned pumpkin',
#    'raisins'],
#   ['flour',
#    'baking powder',
#    'baking soda',
#    'ground cloves',
#    'ground cinnamon',
#    'ground nutmeg',
#    'salt',
#    'solid pack pumpkin',
#    'sugar',
#    'eggs',
#    'walnuts',
#    'raisins',
#    "confectioners' sugar",
#    'orange, zest of',
#    'walnuts'],
#   ['flour',
#    'baking powder',
#    'baking soda',
#    'salt',
#    'cinnamon',
#    'sugar',
#    'water',
#    'pumpkin',
#    'eggs',
#    'raisins'],
#   ['flour',
#    'baking soda',
#    'cinnamon',
#    'baking powder',
#    'ground cloves',
#    'ground nutmeg',
#    'salt',
#    'solid pack pumpkin',
#    'sugar',
#    'eggs',
#    'raisins',
#    "confectioners' sugar",
#    'orange, zest of'],
#   ['nonfat milk',
#    'eggs',
#    'pumpkin',
#    'all-purpose flour',
#    'quick-cooking oats',
#    'sugar',
#    'baking powder',
#    'ground cinnamon',
#    'baking soda',
#    'salt',
#    'raisins',
#    'pecans'],
#   ['sugar',
#    'eggs',
#    'flour',
#    'butter',
#    'baking soda',
#    'salt',
#    'ground cinnamon',
#    'ground nutmeg',
#    'ground ginger',
#    'ground cloves',
#    'pumpkin',
#    'pecans'],
#   ['all-purpose flour',
#    'baking soda',
#    'baking powder',
#    'salt',
#    'cinnamon',
#    'clove',
#    'ginger',
#    'butter',
#    'sugar',
#    'eggs',
#    'fresh pumpkin puree',
#    'lemons',
#    'vanilla',
#    'sour cream',
#    'half cream',
#    'evaporated milk'],
#   ['pumpkin',
#    'eggs',
#    'water',
#    'sugar',
#    'flour',
#    'baking soda',
#    'cinnamon',
#    'salt',
#    'nutmeg'],
#   ['flour',
#    'baking soda',
#    'salt',
#    'nutmeg',
#    'cinnamon',
#    'sugar',
#    'other shortening',
#    'eggs',
#    'water',
#    'pumpkin',
#    'pure vanilla extract'],
#   ['sugar',
#    'canned pumpkin',
#    'water',
#    'eggs',
#    'all-purpose flour',
#    'baking soda',
#    'salt',
#    'ground cloves',
#    'ground cinnamon',
#    'ground nutmeg',
#    'baking powder',
#    'pecans'],
#   ['sugar',
#    'eggs',
#    'vanilla',
#    'pumpkin',
#    'all-purpose flour',
#    'cinnamon',
#    'clove',
#    'ginger',
#    'nutmeg',
#    'baking powder',
#    'baking soda',
#    'salt',
#    'pecans',
#    'walnuts'],
#   ['sugar',
#    'eggs',
#    'solid pack pumpkin',
#    'water',
#    'all-purpose flour',
#    'clove',
#    'baking soda',
#    'salt',
#    'baking powder',
#    'nutmeg',
#    'allspice',
#    'cinnamon'],
#   ['sugar',
#    'eggs',
#    'solid pack pumpkin',
#    'pure vanilla extract',
#    'all-purpose flour',
#    'salt',
#    'baking powder',
#    'baking soda',
#    'ground cinnamon',
#    'ground cloves',
#    'ground nutmeg'],
#   ['flour',
#    'sugar',
#    'baking soda',
#    'baking powder',
#    'table salt',
#    'allspice',
#    'cinnamon',
#    'eggs',
#    'water',
#    'pumpkin'],
#   ['flour',
#    'baking soda',
#    'salt',
#    'cinnamon',
#    'nutmeg',
#    'ginger',
#    'instant butterscotch pudding mix',
#    'pecans',
#    'lemon pudding mix',
#    'eggs',
#    'sugar',
#    'light brown sugar',
#    'pumpkin',
#    'pure vanilla extract'],
#   ['eggs',
#    'fresh pumpkin puree',
#    'flour',
#    'sugar',
#    'vanilla pudding mix',
#    'baking soda',
#    'ground cinnamon',
#    'salt'],
#   ['self rising flour',
#    'Holiday Pumpkin Pie Spice',
#    'instant vanilla pudding',
#    'eggs',
#    'fresh pumpkin puree',
#    'light brown sugar',
#    'apple',
#    'light brown sugar',
#    'flour',
#    'butter'],
#   ['sugar',
#    'eggs',
#    'pumpkin',
#    'flour',
#    'baking soda',
#    'salt',
#    'ground cloves',
#    'cinnamon',
#    'nutmeg',
#    'allspice',
#    'water',
#    'craisins'],
#   ['sugar',
#    'all-purpose flour',
#    'ground cloves',
#    'ground cinnamon',
#    'ground nutmeg',
#    'baking soda',
#    'salt',
#    'baking powder',
#    'eggs',
#    'solid pack pumpkin'],
#   ['pecans',
#    'flour',
#    'baking powder',
#    'baking soda',
#    'ground cinnamon',
#    'ground nutmeg',
#    'salt',
#    'butter',
#    'sugar',
#    'light brown sugar',
#    'vanilla',
#    'eggs',
#    'pumpkin',
#    'evaporated milk',
#    'maple syrup',
#    'cream cheese',
#    'butter',
#    'honey',
#    'powdered sugar'],
#   ['all-purpose flour',
#    'baking soda',
#    'salt',
#    'sugar',
#    'ground nutmeg',
#    'ground cinnamon',
#    'eggs',
#    'water',
#    'canned pumpkin',
#    'walnuts',
#    'golden raisins'],
#   ['flour',
#    'baking soda',
#    'salt',
#    'cinnamon',
#    'nutmeg',
#    'sugar',
#    'eggs',
#    'water',
#    'pumpkin'],
#   ['sugar',
#    'eggs',
#    'fresh pumpkin puree',
#    'flour',
#    'baking soda',
#    'salt',
#    'baking powder',
#    'nutmeg',
#    'allspice',
#    'cinnamon',
#    'ground cloves',
#    'water'],
#   ['granulated sugar',
#    'cream cheese',
#    'sweet unsalted butter',
#    'eggs',
#    'pumpkin',
#    'all-purpose flour',
#    'baking soda',
#    'salt',
#    'cinnamon',
#    'baking powder',
#    'ground cloves',
#    'pecans'],
#   ['sugar',
#    'Splenda sugar substitute',
#    'light brown sugar',
#    'canned pumpkin',
#    'pure vanilla extract',
#    'eggs',
#    'water',
#    'all-purpose flour',
#    'baking soda',
#    'salt',
#    'Holiday Pumpkin Pie Spice'],
#   ['white sugar',
#    'pumpkin',
#    'water',
#    'eggs',
#    'all-purpose flour',
#    'cinnamon',
#    'ground nutmeg',
#    'baking soda',
#    'salt',
#    'walnuts'],
#   ['sugar',
#    'fresh pumpkin puree',
#    'eggs',
#    'applesauce',
#    'flour',
#    'baking powder',
#    'cinnamon',
#    'clove',
#    'salt',
#    'dates',
#    'walnuts'],
#   ['flour',
#    'baking soda',
#    'salt',
#    'cinnamon',
#    'nutmeg',
#    'eggs',
#    'water',
#    'pumpkin',
#    'sugar'],
#   ['white sugar',
#    'baking soda',
#    'ground cloves',
#    'nutmeg',
#    'flour',
#    'baking powder',
#    'salt',
#    'cinnamon',
#    'ginger',
#    'water',
#    'pumpkin',
#    'eggs'],
#   ['eggs',
#    'water',
#    'pumpkin',
#    'flour',
#    'sugar',
#    'baking soda',
#    'salt',
#    'cinnamon',
#    'nutmeg',
#    'ground cloves'],
#   ['sugar',
#    'baking soda',
#    'baking powder',
#    'salt',
#    'ground cloves',
#    'ground nutmeg',
#    'cinnamon',
#    'flour',
#    'eggs',
#    'fresh pumpkin puree',
#    'water',
#    'chocolate chips'],
#   ['all-purpose flour',
#    'baking powder',
#    'baking soda',
#    'Holiday Pumpkin Pie Spice',
#    'salt',
#    'sweet unsalted butter',
#    'sugar',
#    'eggs',
#    'canned pumpkin puree',
#    'pure vanilla extract',
#    'bittersweet chocolate'],
#   ['all-purpose flour',
#    'baking powder',
#    'baking soda',
#    'salt',
#    'cinnamon',
#    'nutmeg',
#    'other shortening',
#    'white sugar',
#    'vanilla',
#    'eggs',
#    'canned pumpkin',
#    'water',
#    'walnuts'],
#   ['clove',
#    'flour',
#    'baking soda',
#    'salt',
#    'cinnamon',
#    'nutmeg',
#    'sugar',
#    'eggs',
#    'water',
#    'pumpkin'],
#   ['all-purpose flour',
#    'whole wheat bread flour',
#    'cinnamon',
#    'salt',
#    'baking soda',
#    'eggs',
#    'sugar',
#    'canned pumpkin',
#    'applesauce',
#    'chocolate chips'],
#   ['flour',
#    'salt',
#    'sugar',
#    'baking soda',
#    'fresh pumpkin puree',
#    'extra virgin olive oil',
#    'eggs',
#    'nutmeg',
#    'cinnamon',
#    'allspice'],
#   ['flour',
#    'sugar',
#    'baking soda',
#    'ground cloves',
#    'ground cinnamon',
#    'ground nutmeg',
#    'salt',
#    'baking powder',
#    'eggs'],
#   ['fresh pumpkin puree', 'eggs', 'sugar', 'salt', 'baking soda', 'flour'],
#   ['walnut flour',
#    'powdered soy protein concentrate',
#    'salt',
#    'baking powder',
#    'walnuts',
#    'bittersweet chocolate',
#    'pumpkin',
#    'eggs',
#    'pure vanilla extract',
#    'sweet unsalted butter'],
#   ['flour',
#    'baking soda',
#    'salt',
#    'cinnamon',
#    'nutmeg',
#    'sugar',
#    'eggs',
#    'pumpkin',
#    'water'],
#   ['applesauce',
#    'eggs',
#    'pumpkin',
#    'sugar',
#    'cinnamon',
#    'nutmeg',
#    'baking soda',
#    'flour',
#    'salt'],
#   ['flour',
#    'sugar',
#    'Holiday Pumpkin Pie Spice',
#    'baking soda',
#    'baking powder',
#    'salt',
#    'eggs',
#    'pumpkin',
#    'butter',
#    'chocolate chips'],
#   ['eggs',
#    'flour',
#    'cinnamon',
#    'baking soda',
#    'instant coconut cream pudding mix',
#    'sugar',
#    'canned pumpkin',
#    'salt',
#    'Holiday Pumpkin Pie Spice'],
#   ['canned pumpkin',
#    'butter',
#    'egg',
#    'sugar',
#    'flour',
#    'salt',
#    'baking powder',
#    'baking soda',
#    'cinnamon',
#    'nutmeg',
#    'clove'],
#   ['pumpkin',
#    'sugar',
#    'eggs',
#    'flour',
#    'baking soda',
#    'salt',
#    'nutmeg',
#    'clove',
#    'cinnamon',
#    'chocolate chips'],
#   ['sugar',
#    'eggs',
#    'pumpkin',
#    'water',
#    'flour',
#    'salt',
#    'baking soda',
#    'clove',
#    'nutmeg',
#    'cinnamon',
#    'allspice'],
#   ['all-purpose flour',
#    'sugar',
#    'ground cinnamon',
#    'baking soda',
#    'salt',
#    'ground ginger',
#    'nutmeg',
#    'clove',
#    'eggs',
#    'canned pumpkin',
#    'cranberries'],
#   ['all-purpose flour',
#    'granulated sugar',
#    'baking soda',
#    'ground cinnamon',
#    'ground nutmeg',
#    'salt',
#    'pumpkin',
#    'eggs',
#    'water',
#    'vanilla'],
#   ['all-purpose flour',
#    'baking soda',
#    'salt',
#    'ground cinnamon',
#    'ground nutmeg',
#    'sugar',
#    'butter',
#    'eggs',
#    'water',
#    'pumpkin',
#    'pecans',
#    'sugar'],
#   ['flour',
#    'baking powder',
#    'baking soda',
#    'salt',
#    'ground ginger',
#    'nutmeg',
#    'allspice',
#    'cinnamon',
#    'sweet unsalted butter',
#    'light brown sugar',
#    'granulated sugar',
#    'orange, zest of',
#    'eggs',
#    'fresh pumpkin puree',
#    'water',
#    'orange, zest of',
#    'fresh ginger',
#    'ground ginger',
#    'sugar'],
#   ['all-purpose flour',
#    'ground cinnamon',
#    'ground nutmeg',
#    'baking soda',
#    'salt',
#    'white sugar',
#    'fresh pumpkin puree',
#    'water',
#    'eggs'],
#   ['sugar',
#    'baking soda',
#    'salt',
#    'baking powder',
#    'cinnamon',
#    'nutmeg',
#    'clove',
#    'ginger',
#    'pumpkin',
#    'eggs',
#    'water'],
#   ['flour',
#    'salt',
#    'sugar',
#    'baking soda',
#    'pumpkin',
#    'olive oil',
#    'eggs',
#    'water',
#    'nutmeg',
#    'cinnamon',
#    'allspice',
#    'walnuts'],
#   ['pumpkin',
#    'chocolate chips',
#    'sugar',
#    'all-purpose flour',
#    'eggs',
#    'baking soda',
#    'ground cinnamon',
#    'water',
#    'salt',
#    'ground nutmeg'],
#   ['butter',
#    'light brown sugar',
#    'egg',
#    'vanilla',
#    'evaporated milk',
#    'pudding mix',
#    'flour',
#    'pumpkin',
#    'cinnamon',
#    'nutmeg',
#    'salt',
#    'baking powder',
#    'baking soda',
#    'light brown sugar',
#    'pecans',
#    'cinnamon',
#    'nutmeg'],
#   ['sugar',
#    'eggs',
#    'pumpkin',
#    'water',
#    'vanilla',
#    'flour',
#    'baking soda',
#    'cinnamon',
#    'nutmeg',
#    'salt'],
#   ['sugar',
#    'other shortening',
#    'pumpkin',
#    'water',
#    'eggs',
#    'all-purpose flour',
#    'baking soda',
#    'salt',
#    'ground cinnamon',
#    'ground cloves',
#    'vanilla',
#    'baking powder'],
#   ['other shortening',
#    'sugar',
#    'eggs',
#    'water',
#    'flour',
#    'baking soda',
#    'salt',
#    'baking powder',
#    'cinnamon',
#    'Holiday Pumpkin Pie Spice'],
#   ['fresh pumpkin puree',
#    'eggs',
#    'water',
#    'granulated sugar',
#    'all-purpose flour',
#    'whole wheat bread flour',
#    'pure vanilla extract',
#    'baking soda',
#    'salt',
#    'ground cinnamon',
#    'ground nutmeg',
#    'ground cloves',
#    'ground ginger']],
#  'Cajun Chops': [['salt',
#    'fresh cayenne pepper',
#    'dried rubbed sage',
#    'paprika',
#    'black pepper',
#    'garlic powder'],
#   ['butter',
#    'paprika',
#    'ground cumin',
#    'salt',
#    'dried rubbed sage',
#    'ground white pepper',
#    'fresh cayenne pepper',
#    'boneless center cut pork chops'],
#   ['paprika',
#    'seasoning salt',
#    'sage',
#    'fresh cayenne pepper',
#    'black pepper',
#    'garlic powder',
#    'boneless pork loin chops',
#    'butter']],
#  'Aussie Meat Pie': [['plain flour',
#    'eggs',
#    'water',
#    'premade puff pastry',
#    'onions',
#    'minced beef',
#    'white Worcestershire sauce',
#    'dark soy sauce',
#    'water',
#    'ground allspice',
#    'cornflour',
#    'water'],
#   ['onion',
#    'lean ground beef',
#    'water',
#    'beef bouillon cube',
#    'tomato sauce',
#    'white Worcestershire sauce',
#    'pepper',
#    'ground oregano',
#    'nutmeg',
#    'plain flour',
#    'puff pastry',
#    'egg'],
#   ['onion',
#    'minced beef',
#    'water',
#    'beef bouillon cube',
#    'tomato sauce',
#    'ground oregano',
#    'white Worcestershire sauce',
#    'nutmeg',
#    'plain flour',
#    'puff pastry',
#    'milk'],
#   ['frozen puff pastry',
#    'ground beef',
#    'onion',
#    'green chili',
#    'flour',
#    'white Worcestershire sauce',
#    'tomato paste',
#    'light brown sugar',
#    'beef broth',
#    'salt',
#    'pepper',
#    'butter',
#    'egg',
#    'water'],
#   ['flour',
#    'fresh ground black pepper',
#    'salt',
#    'water',
#    'frozen puff pastry',
#    'egg'],
#   ['olive oil',
#    'bacon',
#    'tomato paste',
#    'plain flour',
#    'fresh thyme leave',
#    'premade puff pastry',
#    'egg',
#    'tomato sauce']],
#  'Butterscotch Cake': [['self rising flour',
#    'granulated sugar',
#    'sour cream',
#    'instant butterscotch pudding mix',
#    'water',
#    'eggs'],
#   ['boiling water',
#    'quick-cooking oatmeal',
#    'sugar',
#    'light brown sugar',
#    'butter',
#    'margarine',
#    'eggs',
#    'flour',
#    'baking soda',
#    'salt',
#    'cinnamon',
#    'nutmeg',
#    'raisins'],
#   ['milk', 'instant butterscotch pudding mix', 'pecans'],
#   ['instant butterscotch pudding mix', 'milk', 'pecans', 'walnuts'],
#   ['butterscotch pudding', 'eggs', 'sugar']],
#  'Breakfast Casserole': [['butter',
#    'pepper',
#    'flour',
#    'milk',
#    'eggs',
#    'bacon',
#    'cheddar cheese',
#    'onion',
#    'mushroom stems and pieces',
#    'butter',
#    'paprika'],
#   ['eggs', 'reduced-fat sharp cheddar cheese'],
#   ['bulk sausage',
#    'reduced-fat sharp cheddar cheese',
#    'eggs',
#    'milk',
#    'salt',
#    'dry mustard'],
#   ['hash browns',
#    'bacon',
#    'sausage',
#    'eggs',
#    'Velveeta cheese',
#    'cheddar cheese'],
#   ['bacon',
#    'sausage',
#    'onion',
#    'fresh mushrooms',
#    'tomatoes',
#    'eggs',
#    'milk',
#    'dijon-style mustard',
#    'fresh ground black pepper',
#    'herbs',
#    'cheddar cheese'],
#   ['bulk sausage',
#    'cheddar cheese',
#    'eggs',
#    'milk',
#    'dry mustard',
#    'salt',
#    'onion powder',
#    'garlic powder'],
#   ['chicken stove top stuffing mix', 'milk', 'eggs', 'cheddar cheese', 'salt'],
#   ['pork sausage',
#    'cooked ham',
#    'medium cheddar',
#    'swiss cheese',
#    'eggs',
#    'milk',
#    'salt',
#    'pepper',
#    'dry mustard',
#    'white Worcestershire sauce'],
#   ['eggs',
#    'milk',
#    'salt',
#    'pepper',
#    'Velveeta cheese',
#    'dry mustard',
#    'bacon'],
#   ['cheese', 'eggs', 'milk'],
#   ['sausage',
#    'reduced-fat sharp cheddar cheese',
#    'eggs',
#    'milk',
#    'dry mustard'],
#   ['eggs',
#    'sausage',
#    'cheddar cheese',
#    'cheese',
#    'mushroom stems and pieces',
#    'onion',
#    'sweet bell pepper',
#    'milk'],
#   ['pork sausage', 'cheddar cheese', 'eggs', 'salt', 'pepper'],
#   ['bulk pork sausage', 'cheddar cheese', 'eggs', 'milk', 'salt', 'pepper'],
#   ['pork sausage',
#    'onion',
#    'frozen shredded hash browns',
#    'cheddar cheese',
#    'eggs',
#    'onion powder',
#    'milk',
#    'seasoning salt'],
#   ['breakfast sausage',
#    'potatoes',
#    'butter',
#    'mild cheddar cheese',
#    'onion',
#    'green chili',
#    'small curd cottage cheese',
#    'eggs'],
#   ['sausage', 'eggs', 'cheddar cheese', 'Salsa'],
#   ['sausage',
#    'ham',
#    'milk',
#    'ground mustard',
#    'eggs',
#    'salt',
#    'cheddar cheese'],
#   ['frozen hash brown potatoes',
#    'bacon',
#    'cooked ham',
#    'onion',
#    'green bell pepper',
#    'cheddar cheese',
#    'low-fat monterey jack cheese',
#    'egg',
#    'milk',
#    'salt',
#    'pepper'],
#   ['Egg Beaters egg substitute',
#    'egg',
#    'green onion',
#    'milk',
#    'reduced-fat sharp cheddar cheese',
#    'breakfast sausage',
#    'ground mustard',
#    'salt',
#    'pepper',
#    'garlic powder'],
#   ['mushroom stems and pieces',
#    'onion',
#    'butter',
#    'eggs',
#    'mozzarella cheese'],
#   ['Velveeta cheese',
#    'low-fat monterey jack cheese',
#    'swiss cheese',
#    'sour cream',
#    'milk',
#    'ham',
#    'bacon bits',
#    'green chili',
#    'biscuit mix',
#    'self rising flour',
#    'eggs',
#    'frozen shredded hash browns',
#    'garlic powder',
#    'onion powder',
#    'fresh cayenne pepper',
#    'paprika'],
#   ['eggs',
#    'milk',
#    'cheddar cheese',
#    'sausage',
#    'bacon',
#    'green onion',
#    'hash brown patties',
#    'salt',
#    'pepper',
#    'dry mustard'],
#   ['bulk sausage', 'eggs', 'milk', 'cheddar cheese'],
#   ['milk',
#    'green onion',
#    'butter',
#    'mushrooms',
#    'muenster cheese',
#    'cilantro leaves',
#    'fresh parsley leaves',
#    'eggs',
#    'salt',
#    'pepper',
#    'water'],
#   ['pork sausage', 'milk', 'eggs', 'cheddar cheese', 'salt', 'pepper'],
#   ['mild sausage',
#    'mozzarella cheese',
#    'reduced-fat sharp cheddar cheese',
#    'eggs',
#    'milk',
#    'pepper'],
#   ['sausage', 'eggs', 'milk', 'swiss cheese'],
#   ['pork sausage',
#    'reduced-fat sharp cheddar cheese',
#    'eggs',
#    'milk',
#    'salt',
#    'dry mustard',
#    'white Worcestershire sauce'],
#   ['bacon',
#    'green onion',
#    'butter',
#    'egg',
#    'salt',
#    'black pepper',
#    'butter',
#    'flour',
#    'milk',
#    'reduced-fat sharp cheddar cheese',
#    'salt',
#    'black pepper'],
#   ['potatoes',
#    'bacon',
#    'scallion',
#    'eggs',
#    'fresh parmesan cheese',
#    'milk',
#    'cheddar cheese'],
#   ['eggs', 'milk', 'hash browns', 'bacon', 'ham', 'cheese'],
#   ['breakfast sausage',
#    'eggs',
#    'milk',
#    'dry mustard',
#    'cheddar cheese',
#    'colby-monterey jack cheese',
#    'chopped tomato',
#    'sweet bell pepper',
#    'green onion',
#    'potato',
#    'green chili'],
#   ['cheddar cheese', 'mozzarella cheese', 'eggs', 'milk', 'salt', 'pepper'],
#   ['eggs',
#    'milk',
#    'dry mustard',
#    'salt',
#    'black pepper',
#    'reduced-fat sharp cheddar cheese',
#    'pork sausage',
#    'mushroom',
#    'tomatoes',
#    'green onion'],
#   ['frozen hash brown potatoes',
#    'bacon',
#    'sausage',
#    'green chili',
#    'cheddar cheese',
#    'egg',
#    'milk',
#    'dry mustard'],
#   ['English muffin',
#    'butter',
#    'cheddar cheese',
#    'mozzarella cheese',
#    'onion',
#    'eggs',
#    'milk',
#    'salt',
#    'pepper',
#    'bacon bits'],
#   ['seasoned croutons',
#    'swiss cheese',
#    'eggs',
#    'milk',
#    'pork sausage',
#    'mustard'],
#   ['onion',
#    'green chili',
#    'ham',
#    'cheddar cheese',
#    'egg',
#    'milk',
#    'hash brown potatoes',
#    'salt',
#    'pepper',
#    'parsley flakes'],
#   ['sausage',
#    'butter',
#    'cheese',
#    'eggs',
#    'half-and-half',
#    'salt',
#    'dry mustard'],
#   ['skim milk',
#    'lean ham',
#    'eggs',
#    'egg substitute',
#    '2% cheddar cheese',
#    'salt'],
#   ['pork sausage links', 'scallion', 'sour cream', 'Salsa'],
#   ['bacon', 'onion', 'green chili', 'eggs', 'milk']],
#  'Bean Dip': [['red kidney beans'],
#   ['avocado',
#    'Miracle Whip',
#    'black olives',
#    'green chili',
#    'tomatoes',
#    'green onion',
#    'cheddar cheese'],
#   ['ground beef',
#    'onion',
#    'garlic',
#    'green chili',
#    'low-fat monterey jack cheese',
#    'cheddar cheese',
#    'sour cream',
#    'salt',
#    'avocado',
#    'green onion',
#    'tomatoes',
#    'corn tortilla chips'],
#   ['black beans',
#    'pinto beans',
#    'Salsa',
#    'salt',
#    'black pepper',
#    'cumin',
#    'garlic powder'],
#   ['canned pinto beans', 'Salsa', 'colby cheese'],
#   ['sour cream', 'cayenne powder']],
#  'Decadent Chocolate Delight': [['sour cream',
#    'chocolate chips',
#    'water',
#    'eggs',
#    'instant chocolate pudding mix',
#    'vanilla ice cream'],
#   ['sour cream', 'water', 'eggs', 'instant chocolate pudding mix'],
#   ['light sour cream',
#    'water',
#    'egg',
#    'instant chocolate pudding mix',
#    'ice cream']],
#  'Polish Dill Pickle Soup': [['beef broth',
#    'instant flour',
#    'milk',
#    'butter',
#    'dill pickles',
#    'potatoes',
#    'fresh dill'],
#   ['dill pickles',
#    'pickle juice',
#    'potatoes',
#    'instant flour',
#    'milk',
#    'egg',
#    'butter',
#    'fresh dill',
#    'sour cream'],
#   ['chicken broth',
#    'carrots',
#    'potatoes',
#    'dill pickles',
#    'milk',
#    'flour',
#    'egg',
#    'sour cream',
#    'celery'],
#   ['chicken broth',
#    'carrots',
#    'potatoes',
#    'dill pickles',
#    'milk',
#    'flour',
#    'egg',
#    'sour cream',
#    'celery']],
#  'Creamed Mushrooms': [['white mushrooms',
#    'mushroom',
#    'shallot',
#    'sweet unsalted butter',
#    'cognac',
#    'chicken broth',
#    'heavy cream',
#    'paprika',
#    'flat leaf parsley',
#    'sour cream'],
#   ['white mushrooms',
#    'sweet butter',
#    'salt',
#    'fresh ground black pepper',
#    'nutmeg',
#    'heavy cream',
#    'madeira wine',
#    'soya sauce',
#    'Italian parsley'],
#   ['mushroom', 'butter', 'salt', 'ground white pepper', 'butter']],
#  'Chicken Jambalaya': [['chicken breasts',
#    'salt',
#    'fresh ground black pepper',
#    'onions',
#    'green bell pepper',
#    'celery',
#    'minced  fresh garlic cloves',
#    'fresh cayenne pepper',
#    'chicken broth',
#    'chopped tomato'],
#   ['onion',
#    'minced  fresh garlic cloves',
#    'butter',
#    'smoked sausage',
#    'chicken broth',
#    'diced tomatoes with juice',
#    'green chili',
#    'bay leaf',
#    'cayenne',
#    'dried thyme leaves',
#    'long-grain rice',
#    'medium shrimp',
#    'tomato sauce'],
#   ['chicken breasts',
#    'red onions',
#    'minced  fresh garlic cloves',
#    'chopped tomato',
#    'sweet brown rice',
#    'chili powder',
#    'paprika',
#    'dried oregano',
#    'kernel corn',
#    'peas'],
#   ['chicken pieces',
#    'kosher salt',
#    'celery',
#    'green bell pepper',
#    'onion',
#    'garlic',
#    'andouille sausage',
#    'smoked ham',
#    'rice',
#    'whole tomatoes',
#    'tomato paste',
#    'white Worcestershire sauce',
#    'bay leaves',
#    'fresh thyme',
#    'green onion']],
#  'Chinese Chicken Wings': [['chicken wings',
#    'honey',
#    'soya sauce',
#    'ginger',
#    'minced  fresh garlic cloves',
#    'five-spice powder',
#    'ground white pepper',
#    'sesame seeds',
#    'green onion'],
#   ['chicken wings',
#    'soya sauce',
#    'light brown sugar',
#    'ginger powder',
#    'garlic powder'],
#   ['chicken wings',
#    'honey',
#    'soya sauce',
#    'light brown sugar',
#    'fresh garlic',
#    'lemon juice',
#    'peppercorn',
#    'hot water'],
#   ['chicken wings',
#    'honey',
#    'chili sauce',
#    'salt',
#    'soya sauce',
#    'garlic powder'],
#   ['chicken wings',
#    'sugar',
#    'cornstarch',
#    'salt',
#    'ground ginger',
#    'pepper',
#    'water',
#    'lemon juice',
#    'soya sauce'],
#   ['chicken wings', 'soya sauce'],
#   ['szechwan pepper',
#    'peppercorn',
#    'soya sauce',
#    'green onion',
#    'garlic',
#    'gingerroot',
#    'chicken wings'],
#   ['chicken wings',
#    'soya sauce',
#    'minced  fresh garlic cloves',
#    'ground ginger',
#    'lemon juice',
#    'msg'],
#   ['chicken wings',
#    'sugar',
#    'cornstarch',
#    'salt',
#    'ground ginger',
#    'pepper',
#    'water',
#    'lemon juice',
#    'soya sauce'],
#   ['chicken wings',
#    'soya sauce',
#    'minced  fresh garlic cloves',
#    'fresh ginger',
#    'sherry wine',
#    'honey'],
#   ['chicken wings',
#    'soya sauce',
#    'sugar',
#    'light brown sugar',
#    'vinegar',
#    'chicken broth'],
#   ['chicken wings',
#    'lemon peel',
#    'lemon juice',
#    'sugar',
#    'sherry wine',
#    'soya sauce',
#    'chili sauce',
#    'salt',
#    'ginger',
#    'cornstarch',
#    'water',
#    'black sesame seeds',
#    'sesame seeds',
#    'scallion'],
#   ['chicken wings',
#    'all-purpose flour',
#    'salt',
#    'paprika',
#    'pepper',
#    'creamy peanut butter',
#    'water',
#    'light brown sugar',
#    'lemon juice',
#    'soya sauce',
#    'ground ginger']],
#  'Cajun Coleslaw': [['mayonnaise',
#    'yellow mustard',
#    'ketchup',
#    'olive oil',
#    'wine vinegar',
#    'salt',
#    'sweet bell peppers',
#    'onions',
#    'cabbage'],
#   ['mayonnaise',
#    'yellow mustard',
#    'olive oil',
#    'lemon',
#    'Tabasco sauce',
#    'ketchup',
#    'wine vinegar',
#    'white Worcestershire sauce',
#    'salt',
#    'cabbage',
#    'sweet bell peppers',
#    'onions'],
#   ['green chili',
#    'green onion',
#    'celery',
#    'parsley',
#    'mayonnaise',
#    'apple cider vinegar',
#    'milk',
#    'sugar',
#    'Tabasco sauce']],
#  'Crunchy Chicken': [['chicken',
# ...
#   ['instant chocolate pudding mix',
#    'eggs',
#    'Kahlua',
#    'powdered sugar',
#    'Kahlua'],
#   ['sour cream', 'eggs', 'Kahlua', 'powdered sugar', 'powdered sugar'],
#   ['eggs', 'sour cream', 'Kahlua', 'sugar', 'butter', 'salt', 'Kahlua'],
#   ['vanilla',
#    'instant chocolate pudding mix',
#    'sour cream',
#    'eggs',
#    'Kahlua',
#    'light brown sugar',
#    'pecans',
#    'real butter',
#    'Kahlua',
#    'powdered sugar'],
#   ['instant chocolate pudding mix',
#    'chocolate chips',
#    'eggs',
#    'sour cream',
#    'Kahlua',
#    'powdered sugar',
#    'walnuts'],
#   ['instant chocolate pudding mix',
#    'eggs',
#    'sour cream',
#    'Kahlua',
#    'chocolate chips',
#    'powdered sugar'],
#   ['chocolate instant pudding', 'sour cream', 'eggs', 'Kahlua'],
#   ['eggs',
#    'sour cream',
#    'chocolate chips',
#    'Kahlua',
#    'Amaretto',
#    'powdered sugar'],
#   ['sour cream', 'eggs', 'Kahlua', 'instant vanilla pudding'],
#   ['sour cream',
#    'chocolate chips',
#    'eggs',
#    'Kahlua',
#    'instant vanilla pudding',
#    'powdered sugar'],
#   ['chocolate instant pudding', 'Cool Whip']],
#  'Chinese-Style Spareribs': [['butter',
#    'margarine',
#    'garlic',
#    'tomato puree',
#    'light brown sugar',
#    'soya sauce',
#    'white vinegar',
#    'chili sauce'],
#   ['Hoisin Sauce Recipe',
#    'water',
#    'dry sherry',
#    'honey',
#    'soya sauce',
#    'garlic',
#    'ground white pepper'],
#   ['soya sauce', 'ginger orange marmalade', 'ketchup', 'garlic'],
#   ['water', 'beef bouillon cube', 'garlic', 'salt', 'honey', 'soya sauce'],
#   ['soya sauce',
#    'water',
#    'minced  fresh garlic cloves',
#    'dry sherry',
#    'rice wine',
#    'Hoisin Sauce Recipe',
#    'five-spice powder',
#    'vinegar'],
#   ['ground coriander',
#    'chili powder',
#    'light brown sugar',
#    'five-spice powder',
#    'ground fennel',
#    'kosher salt',
#    'kosher salt',
#    'soya sauce',
#    'granulated sugar',
#    'rice vinegar',
#    'fresh ginger',
#    'scallion'],
#   ['dark soy sauce',
#    'maple syrup',
#    'dry sherry',
#    'salt',
#    'sugar',
#    'minced  fresh garlic cloves'],
#   ['soya sauce',
#    'ginger orange marmalade',
#    'ketchup',
#    'minced  fresh garlic cloves',
#    'ground ginger',
#    'orange, juice of',
#    'country-style boneless pork ribs'],
#   ['soya sauce',
#    'honey',
#    'dry sherry',
#    'minced  fresh garlic cloves',
#    'ground ginger',
#    'green onion top',
#    'sesame seeds']],
#  'Broccoli Cheese Chicken Quiche': [['cream cheese',
#    'butter',
#    'flour',
#    'shallots',
#    'green onion',
#    'fresh mushrooms',
#    'butter',
#    'eggs',
#    'half-and-half',
#    'milk',
#    'salt',
#    'fresh ground pepper',
#    'swiss cheese',
#    'diced tomatoes'],
#   ['butter', 'onion', 'flour', 'milk', 'eggs', 'basil', 'salt', 'cheese'],
#   ['broccoli',
#    'Velveeta cheese',
#    'eggs',
#    'heavy cream',
#    'half-and-half',
#    'salt',
#    'pepper'],
#   ['eggs',
#    'onions',
#    'milk',
#    'flour',
#    'salt',
#    'pepper',
#    'cheddar cheese',
#    'fresh broccoli']],
#  'Vegetarian Black Bean Chili': [['baby eggplant',
#    'salt',
#    'button mushroom',
#    'onion',
#    'chili powder',
#    'red sweet bell pepper',
#    'green bell pepper',
#    'garlic',
#    'dried oregano',
#    'dried leaf basil',
#    'ground cumin',
#    'diced tomatoes with juice',
#    'black beans',
#    'tomatoes',
#    'celery',
#    'zucchini',
#    'tofu crumbles'],
#   ['sweet onion',
#    'canola oil',
#    'mushroom',
#    'green chili',
#    'minced  fresh garlic cloves',
#    'black beans',
#    'diced tomatoes',
#    'tomato sauce',
#    'tomato paste',
#    'light brown sugar',
#    'chili powder',
#    'ground cumin'],
#   ['minced  fresh garlic cloves',
#    'onion',
#    'carrot',
#    'tomatoes',
#    'black beans',
#    'chili powder',
#    'ground cumin',
#    'dried rosemary',
#    'salt'],
#   ['onion',
#    'minced  fresh garlic cloves',
#    'chopped tomato',
#    'black beans',
#    'vegetarian ground beef',
#    'beef bouillon cube',
#    'chili powder',
#    'powdered cumin',
#    'fresh cayenne pepper']],
#  'Cranberry Pie': [['fresh cranberries',
#    'sugar',
#    'walnuts',
#    'eggs',
#    'flour',
#    'sugar',
#    'butter'],
#   ['cranberries', 'flour', 'sugar', 'sugar', 'salt'],
#   ['fresh cranberries',
#    'flour',
#    'fine rolled oats',
#    'sweet unsalted butter',
#    'sugar',
#    'light brown sugar',
#    'salt'],
#   ['dried cranberries',
#    'white sugar',
#    'all-purpose flour',
#    'salt',
#    'milk',
#    'eggs',
#    'sour cream',
#    'butter',
#    'heavy whipping cream',
#    "confectioners' sugar",
#    'pure vanilla extract'],
#   ['fresh cranberries',
#    'sugar',
#    'cornstarch',
#    'sugar',
#    'cornstarch',
#    'milk',
#    'salt',
#    'vanilla bean']],
#  'Black Bean Burgers': [['black beans',
#    'sweet onion',
#    'minced  fresh garlic cloves',
#    'sweet basil',
#    'dried oregano',
#    'ground cumin',
#    'eggs'],
#   ['black beans', 'onion', 'garlic', 'egg substitute'],
#   ['black beans',
#    'red onions',
#    'red sweet bell pepper',
#    'ground cumin',
#    'chili powder',
#    'fresh cilantro',
#    'fresh cayenne pepper'],
#   ['black beans',
#    'oats',
#    'onion',
#    'fresh cilantro',
#    'eggs',
#    'salt',
#    'all-purpose flour',
#    'cornmeal'],
#   ['canola oil',
#    'onions',
#    'red sweet bell pepper',
#    'fresh ginger',
#    'minced  fresh garlic cloves',
#    'ground allspice',
#    'ground coriander',
#    'salt',
#    'cooked rice',
#    'black beans',
#    'light mayonnaise',
#    'boston lettuce leaves',
#    'red onions'],
#   ['black beans',
#    'onion',
#    'kernel corn',
#    'thick & chunky salsa',
#    'minced  fresh garlic cloves',
#    'parsley',
#    'cilantro',
#    'salt',
#    'black pepper'],
#   ['black beans', 'red onions', 'chunky salsa', 'ground cumin'],
#   ['black beans',
#    'Rotel Tomatoes',
#    'minced  fresh garlic cloves',
#    'onion powder',
#    'carrot',
#    'old fashioned oats'],
#   ['black beans',
#    'onion',
#    'cumin',
#    'chili powder',
#    'black pepper',
#    'garlic powder',
#    'salt']],
#  'Sweet Potatoes': [['sugar',
#    'butter',
#    'eggs',
#    'milk',
#    'vanilla',
#    'light brown sugar',
#    'flour',
#    'butter'],
#   ['sweet potato',
#    'light brown sugar',
#    'cinnamon',
#    'salt',
#    'butter',
#    'small marshmallows'],
#   ['sweet potato',
#    'sugar',
#    'butter',
#    'eggs',
#    'pure vanilla extract',
#    'light brown sugar',
#    'flour',
#    'butter'],
#   ['sweet unsalted butter', 'milk', 'salt', 'sugar', 'sweet potato', 'salt'],
#   ['sweet potato',
#    'sugar',
#    'butter',
#    'eggs',
#    'vanilla',
#    'coconut',
#    'pecans',
#    'light brown sugar',
#    'flour',
#    'butter']],
#  'Black Forest Coffee': [['brewed coffee',
#    'maraschino cherry juice',
#    'maraschino cherry'],
#   ['brewed coffee',
#    'chocolate milk',
#    'cherry juice',
#    'heavy cream',
#    'cherry juice',
#    'sugar',
#    'bittersweet chocolate',
#    'sweet cherries'],
#   ['maraschino cherry juice', 'coffee', 'dark chocolate'],
#   ['brewed coffee', 'maraschino cherry juice', 'Grand Marnier', 'milk']],
#  'Cucumber Tea Sandwiches': [['English seedless cucumber',
#    'fresh mint leaves',
#    'sweet unsalted butter',
#    'cream cheese',
#    'salt'],
#   ['Creme Fraiche', 'dill', 'English seedless cucumber'],
#   ['butter',
#    'heavy cream',
#    'French mustard',
#    'cucumbers',
#    'salt',
#    'olive oil',
#    'lemon juice',
#    'sugar',
#    'ground white pepper',
#    'butter'],
#   ['English cucumbers', 'sweet unsalted butter'],
#   ['English cucumbers', 'mayonnaise', 'fresh dill'],
#   ['cucumbers', 'butter', 'fresh parsley']],
#  'Cappuccino Pudding': [['instant coffee granules',
#    'boiling water',
#    'skim milk',
#    'fat-free sugar-free instant vanilla pudding mix',
#    'ground cinnamon',
#    'Cool Whip Free',
#    'Cool Whip'],
#   ['instant coffee granules',
#    'boiling water',
#    'skim milk',
#    'fat-free sugar-free instant vanilla pudding mix',
#    'ground cinnamon'],
#   ['instant coffee granules',
#    'boiling water',
#    'milk',
#    'instant vanilla pudding',
#    'instant chocolate pudding mix',
#    'ground cinnamon',
#    'Cool Whip'],
#   ['instant coffee granules',
#    'boiling water',
#    'milk',
#    'instant chocolate pudding mix',
#    'ground cinnamon']],
#  'Potatoes Dauphinoise': [['potatoes',
#    'butter',
#    'margarine',
#    'garlic',
#    'salt',
#    'fresh ground black pepper',
#    'nutmeg',
#    'milk'],
#   ['butter',
#    'water',
#    'salt',
#    'all-purpose flour',
#    'eggs',
#    'potatoes',
#    'ground nutmeg',
#    'black pepper',
#    'panko breadcrumbs',
#    'olive oil'],
#   ['water',
#    'salt',
#    'butter',
#    'margarine',
#    'flour',
#    'eggs',
#    'potato',
#    'butter'],
#   ['potato',
#    'heavy cream',
#    'milk',
#    'minced  fresh garlic cloves',
#    'gruyere cheese']],
#  'Indonesian Peanut Sauce': [['onion',
#    'garlic',
#    'peanut butter',
#    'light brown sugar',
#    'salt',
#    'soya sauce',
#    'vinegar',
#    'water'],
#   ['chunky peanut butter',
#    'garlic',
#    'green chili peppers',
#    'light brown sugar',
#    'unsweetened coconut milk',
#    'soya sauce',
#    'molasses',
#    'fresh lime juice'],
#   ['onion', 'cardamom', 'light brown sugar', 'soya sauce', 'lemon juice'],
#   ['shallot',
#    'minced  fresh garlic cloves',
#    'red pepper flakes',
#    'creamy peanut butter',
#    'light coconut milk',
#    'reduced sodium soy sauce',
#    'light brown sugar',
#    'fresh lime juice',
#    'water']],
#  'Coconut-Cranberry Muffins': [['all-purpose flour',
#    'granulated sugar',
#    'sweetened flaked coconut',
#    'baking powder',
#    'baking soda',
#    'cinnamon',
#    'salt',
#    'buttermilk',
#    'eggs',
#    'vanilla',
#    'cranberries'],
#   ['flour',
#    'sugar',
#    'salt',
#    'cinnamon',
#    'baking powder',
#    'butter',
#    'pure vanilla extract',
#    'egg',
#    'half cream',
#    'blueberries'],
#   ['flour',
#    'sugar',
#    'baking powder',
#    'salt',
#    'dried sweetened cranberries',
#    'coconut milk',
#    'butter',
#    'lemon rind',
#    'pure vanilla extract',
#    'egg',
#    'sugar']],
#  'Braised Lamb Shanks': [['olive oil',
#    'minced  fresh garlic cloves',
#    'onion',
#    'carrot',
#    'tomatoes',
#    'lamb shank',
#    'red wine',
#    'bay leaves',
#    'dried oregano',
#    'dried thyme leaves',
#    'salt',
#    'fresh ground black pepper',
#    'water'],
#   ['lamb shank',
#    'onion',
#    'minced  fresh garlic cloves',
#    'red wine',
#    'flour',
#    'fresh ground black pepper',
#    'bay leaves'],
#   ['cumin seed',
#    'salt',
#    'lamb shank',
#    'olive oil',
#    'onion',
#    'carrot',
#    'celery',
#    'minced  fresh garlic cloves',
#    'tomatoes',
#    'dry red wine',
#    'port wine'],
#   ['lamb shank',
#    'salt',
#    'pepper',
#    'olive oil',
#    'minced  fresh garlic cloves',
#    'onions',
#    'celery',
#    'fresh parsley',
#    'fresh thyme',
#    'bay leaf',
#    'whole black peppercorn'],
#   ['carrots',
#    'onions',
#    'celery ribs',
#    'garlic',
#    'rosemary',
#    'thyme',
#    'bay leaves',
#    'salt',
#    'lamb shank',
#    'dry red wine',
#    'chicken broth',
#    'flour',
#    'tomato paste',
#    'ground white pepper',
#    'parsley',
#    'orange, zest of']],
#  'Bacon and Potato Frittata': [['bacon',
#    'potatoes',
#    'eggs',
#    'milk',
#    'pepper',
#    'salt',
#    'fresh parmesan cheese',
#    'green onion',
#    'fresh basil leaf',
#    'dried leaf basil',
#    'Salsa',
#    'sour cream'],
#   ['olive oil',
#    'yellow onions',
#    'bacon',
#    'garlic',
#    'potatoes',
#    'eggs',
#    'water'],
#   ['bacon',
#    'pepper',
#    'ground nutmeg',
#    'sweet onion',
#    'water',
#    'sugar',
#    'spinach',
#    'mozzarella cheese'],
#   ['bacon',
#    'small red potatoes',
#    'red onions',
#    'rosemary',
#    'dried rosemary',
#    'eggs',
#    'water',
#    'salt',
#    'ground white pepper',
#    'ground paprika'],
#   ['bacon', 'frozen hash brown potatoes', 'green onion', 'eggs'],
#   ['bacon',
#    'olive oil',
#    'onion',
#    'tomatoes',
#    'eggs',
#    'fresh basil leaf',
#    'fresh parmesan cheese'],
#   ['potatoes',
#    'olive oil',
#    'onion',
#    'bacon',
#    'eggs',
#    'milk',
#    'cheddar cheese'],
#   ['bacon',
#    'potatoes',
#    'onion',
#    'eggs',
#    'water',
#    'salt',
#    'black pepper',
#    'cheddar cheese'],
#   ['bacon',
#    'green onion',
#    'green chili',
#    'mushrooms',
#    'salt',
#    'pepper',
#    'potatoes',
#    'eggs',
#    'milk',
#    'swiss cheese',
#    'Salsa'],
#   ['olive oil',
#    'potatoes',
#    'salt',
#    'pepper',
#    'onion',
#    'eggs',
#    'half-and-half',
#    'parsley',
#    'crisp bacon',
#    'tomatoes',
#    'bacon']],
#  'Baked Rice': [['converted white rice',
#    'butter',
#    'mushroom',
#    'fresh parmesan cheese'],
#   ['onion',
#    'butter',
#    "Uncle Ben's converted brand rice",
#    'chicken bouillon cubes',
#    'beef bouillon cube',
#    'boiling water',
#    'mushroom pieces'],
#   ['rice', 'boiling water', 'salt', 'oleo', 'butter'],
#   ['butter',
#    'onion',
#    'minced  fresh garlic cloves',
#    'rice',
#    'chicken broth',
#    'parsley',
#    'thyme',
#    'fresh cayenne pepper',
#    'bay leaf',
#    'pine nuts'],
#   ['rice', 'chicken broth', 'onion', 'butter'],
#   ['white rice', 'mushrooms', 'garlic powder', 'butter'],
#   ['long-grain rice',
#    'chicken broth',
#    'butter',
#    'parsley flakes',
#    'garlic powder'],
#   ['butter',
#    'white rice',
#    'onion',
#    'green chili',
#    'celery',
#    'water',
#    'salt',
#    'pepper',
#    'parsley'],
#   ['raw rice', 'milk', 'sugar', 'butter', 'nutmeg'],
#   ['water', 'long-grain rice', 'butter', 'onion'],
#   ['rice', 'beef broth', 'onion', 'butter'],
#   ['sweet brown rice',
#    'water',
#    'sweet unsalted butter',
#    'kosher salt',
#    'garlic powder',
#    'onions',
#    'ground white pepper',
#    'onion',
#    'celery',
#    'carrot'],
#   ['onion', 'butter', 'long-grain rice', 'water', 'salt'],
#   ['water', 'rice', 'butter']],
#  'Cinnamon Pancakes': [['all-purpose flour',
#    'light brown sugar',
#    'baking powder',
#    'ground cinnamon',
#    'eggs',
#    'milk',
#    'butter'],
#   ['all-purpose flour',
#    'baking powder',
#    'salt',
#    'milk',
#    'canola oil',
#    'egg',
#    'butter',
#    'light brown sugar',
#    'ground cinnamon',
#    'butter',
#    'cream cheese',
#    'powdered sugar',
#    'pure vanilla extract'],
#   ['plain flour',
#    'egg',
#    '2% low-fat milk',
#    'cinnamon',
#    'pure vanilla extract']],
#  "My Family's Favorite Pancakes": [['flour',
#    'baking powder',
#    'salt',
#    'sugar',
#    'milk',
#    'eggs'],
#   ['all-purpose flour',
#    'egg',
#    'buttermilk',
#    'sugar',
#    'baking powder',
#    'baking soda',
#    'vanilla'],
#   ['Bisquick', 'milk', 'eggs'],
#   ['flour', 'baking powder', 'salt', 'sugar', 'eggs', 'milk']],
#  'Thai Pumpkin Soup': [['onion',
#    'ginger',
#    'red chile',
#    'pumpkin',
#    'coconut milk',
#    'garlic'],
#   ['canola oil',
#    'onion',
#    'celery',
#    'Thai red curry paste',
#    'tomatoes',
#    'pumpkin',
#    'coconut milk',
#    'coconut cream',
#    'salt',
#    'coconut cream',
#    'heavy cream',
#    'fresh coriander'],
#   ['coconut milk',
#    'fresh pumpkin',
#    'shallots',
#    'garlic',
#    'lime, zest of',
#    'fresh lemongrass',
#    'limes, juice of',
#    'cilantro'],
#   ['red onions', 'Thai red curry paste', 'coconut milk'],
#   ['onion',
#    'minced  fresh garlic cloves',
#    'Thai red curry paste',
#    'pumpkin',
#    'coconut milk']],
#  'Sex on the Beach': [['vodka', 'sugar'],
#   ['vodka', 'white cranberry juice'],
#   ['vodka', 'white cranberry juice'],
#   ['vodka', 'white cranberry juice']],
#  'Pumpkin Pie Bars': [['butter',
#    'eggs',
#    'canned pumpkin',
#    'milk',
#    'white sugar',
#    'ground cinnamon',
#    'butter'],
#   ['flour',
#    'light brown sugar',
#    'granulated sugar',
#    'cinnamon',
#    'walnuts',
#    'pecans',
#    'butter',
#    'eggs',
#    'canned pumpkin',
#    'Sweetened Condensed Milk',
#    'eggs',
#    'cinnamon',
#    'allspice',
#    'salt'],
#   ['flour',
#    'light brown sugar',
#    'sugar',
#    'butter',
#    'margarine',
#    'old fashioned oats',
#    'quick-cooking oats',
#    'pecans',
#    'cream cheese',
#    'eggs',
#    'pumpkin',
#    'Holiday Pumpkin Pie Spice'],
#   ['real butter',
#    'eggs',
#    'pumpkin pie filling',
#    'evaporated milk',
#    'sugar',
#    'cinnamon',
#    'real butter']],
#  'Broccoli Coleslaw': [['broccoli slaw mix',
#    'red onions',
#    'raisins',
#    'unsalted sunflower seeds',
#    'bacon',
#    'mayonnaise',
#    'vinegar',
#    'sugar',
#    'black pepper'],
#   ['green cabbage',
#    'broccoli florets',
#    'carrot',
#    'green onion',
#    'rice vinegar',
#    'sugar',
#    'soya sauce',
#    'garlic',
#    'fresh ginger',
#    'black pepper'],
#   ['red cabbage',
#    'green cabbage',
#    'carrots',
#    'cucumbers',
#    'broccoli',
#    'mayonnaise',
#    'vinegar',
#    'sugar']],
#  ...}

# %%
vsrep = [v for v in vs if len(vs[v])>1]

# %%
vrids = [vs[v] for v in vsrep]

# %%
recipesdf['NoIngredients'] = [len(ing) for ing in recipesdf['RecipeIngredientParts'].values]

# %%
recipesdf.loc[recipesdf.NoIngredients>5]
# Out:
#                                               Name  RecipeCategory  \
# RecipeId
# 524289             Apple-Glazed Stuffed Pork Chops            Pork
# 524301                  Bob's Taco Soup With Pasta   One Dish Meal
# 524315    Crispy Chicken Thighs in Convection Oven         Poultry
# 39                                         Biryani  Chicken Breast
# 41                  Carina's Tofu-Vegetable Kebabs        Soy/Tofu
# ...                                            ...             ...
# 524062                             Bisquick Crepes       Breakfast
# 524149                Hidden Veggie Mac and Cheese       < 60 Mins
# 524229       Coconut Curried Butternut Squash Soup    Lactose Free
# 524235                   Paleo Party Pork Carnitas            Pork
# 524236                      Paleo Pork Chili Verde            Pork
#
#                                       RecipeIngredientParts TotalTime  \
# RecipeId
# 524289    [bacon, leeks, other dry white wine, thyme, sa...     PT40M
# 524301    [ground beef, onion, diced tomatoes, red kidne...     PT40M
# 524315    [skinless chicken thighs, light sour cream, mi...    PT1H5M
# 39        [saffron, milk, green chili peppers, onions, g...   PT4H25M
# 41        [extra firm tofu, baby eggplant, zucchini, mus...  PT24H20M
# ...                                                     ...       ...
# 524062    [eggs, Bisquick, milk, butter, cream cheese, s...     PT45M
# 524149    [carrots, cauliflower, low-fat milk, salt, che...     PT40M
# 524229    [olive oil, salt, ground white pepper, carrot,...   PT1H40M
# 524235    [canola oil, dried oregano, minced  fresh garl...   PT8H30M
# 524236    [onion, green bell pepper, canola oil, minced ...     PT45M
#
#           NoIngredients
# RecipeId
# 524289                8
# 524301                8
# 524315               11
# 39                   25
# 41                   14
# ...                 ...
# 524062                7
# 524149                8
# 524229               10
# 524235               13
# 524236                8
#
# [191545 rows x 5 columns]

# %%
vrids
# Out:
# [[9870, 158139],
#  [42974, 91633, 142287, 223553],
#  [43222, 66810, 351699],
#  [51528, 121602, 210303, 213261, 267945, 293717, 355939],
#  [98438, 103960, 111777],
#  [153225, 325358],
#  [157045, 212365, 337754]]
