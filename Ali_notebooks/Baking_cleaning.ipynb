# %%
# Loading packages
import pandas as pd
import os

# %%
# Loading Keywords
keywords_path = '../data/keywords.pk'
keywords_df = pd.read_pickle(keywords_path)

# %% [markdown]
# ## Creating the `baking` Column

# %%
# Cooking related keywords
baking_keywords = ['breads', 'cookie & brownie', 'pie', 'bar cookie', 'drop cookies', 'yeast breads', 'cheesecake']

# Create the `baking` column
def is_baking(row):
    for keyword in row['Keywords']:
        if any(baking_keyword in keyword.lower() for baking_keyword in baking_keywords):
            return True
    return False

keywords_df['baking'] = keywords_df.apply(is_baking, axis=1)
keywords_df.head()
# Out:
#                                                 Name    KeywordsTitle  \
# RecipeId
# 38                 low-fat berry blue frozen dessert        [dessert]
# 40                                     best lemonade          [lemon]
# 42                                      cabbage soup  [cabbage, soup]
# 44                            warm chicken a la king        [chicken]
# 45        buttermilk pie with gingersnap crumb crust            [pie]
#
#                                                    Keywords  baking
# RecipeId
# 38        [frozen desserts, healthy, freezer, dessert, s...   False
# 40                      [healthy, summer, lemon, beverages]   False
# 42        [healthy, vegetable, winter, vegan, cabbage, e...   False
# 44        [noodle, pie, potato, rice, chicken, meat, pou...    True
# 45                 [pie, healthy, dessert, weeknight, oven]    True

# %% [markdown]
# ## Saving Cleaned Data

# %%
# Save DataFrame containing the cleared `baking` column
keywords_df[['baking']].to_parquet('../data/clean_columns/baking.parquet')

# %%
keywords_df.sample(10)
# Out:
#                                                        Name  \
# RecipeId
# 124909    marlboro country chicken fried steak (country ...
# 478                               forepaughs english trifle
# 238198                               red cinnamon apple pie
# 360614                 maple mustard glazed pork tenderloin
# 12263                             peppermint patty brownies
# 490345                      spiced-up butternut squash soup
# 233619      tomato and marinated baby bocconcini appetizers
# 301030                                     cointreau sunset
# 196685                           southern comfort manhattan
# 63858                                   french potato salad
#
#                     KeywordsTitle  \
# RecipeId
# 124909    [fried, chicken, steak]
# 478                            []
# 238198               [apple, pie]
# 360614                     [pork]
# 12263                          []
# 490345                     [soup]
# 233619                         []
# 301030                         []
# 196685                         []
# 63858             [salad, potato]
#
#                                                    Keywords  baking
# RecipeId
# 124909    [lunch/snacks, fried, inexpensive, chicken, st...   False
# 478                    [european, dessert, cake, weeknight]   False
# 238198                                [dessert, pie, apple]    True
# 360614                                   [pork, meat, easy]   False
# 12263     [for large groups, lunch/snacks, bar cookie, c...    True
# 490345    [coconut, vegetable, easy, sweet, thanksgiving...   False
# 233619          [australian, no cook, simple, easy, cheese]   False
# 301030    [citrus, brunch, beverages, australian, fruit,...   False
# 196685                   [cherries, easy, fruit, beverages]   False
# 63858              [potato, vegetable, spring, salad, easy]   False
