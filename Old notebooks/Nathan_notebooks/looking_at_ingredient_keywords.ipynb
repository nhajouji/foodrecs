# %%
import pandas as pd
# from ingredient_parser import parse_ingredient, parse_multiple_ingredients

# %%
df = pd.read_pickle("../data/rec_ingredients.pk")
df
# Out:
#                                               Name  \
# RecipeId
# 524289             Apple-Glazed Stuffed Pork Chops
# 524301                  Bob's Taco Soup With Pasta
# 524315    Crispy Chicken Thighs in Convection Oven
# 38               Low-Fat Berry Blue Frozen Dessert
# 39                                         Biryani
# ...                                            ...
# 524149                Hidden Veggie Mac and Cheese
# 524197                        Refreshing Ice Cubes
# 524229       Coconut Curried Butternut Squash Soup
# 524235                   Paleo Party Pork Carnitas
# 524236                      Paleo Pork Chili Verde
#
#                                       RecipeIngredientParts  \
# RecipeId
# 524289    [bacon, leeks, other dry white wine, thyme, sa...
# 524301    [ground beef, onion, diced tomatoes, red kidne...
# 524315    [skinless chicken thighs, light sour cream, mi...
# 38        [blueberries, granulated sugar, vanilla yogurt...
# ...

# %%
ingredients_list = []
for entry_list in list(df.RecipeIngredientParts):
    ingredients_list += entry_list

ingredients_list = list(set(ingredients_list))
ingredients_list[30:60]
# Out:
# ['Swedish Meatballs',
#  'Garlic Bread Cro&ucirc;tes',
#  'nopales',
#  'barbecue sauce',
#  'red leaf lettuce',
#  'low-fat turkey kielbasa',
#  'skim milk',
#  'white cranberry juice',
#  'soyabean nuggets',
#  'tofu',
#  'iranian rice',
#  'sharp American cheese',
#  'yellow cornmeal',
#  'raspberry ice cream',
#  'chocolate piece',
#  'boneless salmon fillet',
#  'Curtido (Salvadorean Pickled Coleslaw)',
#  'blood orange',
#  'Italian Salad Dressing',
#  'lettuce greens',
#  'strong rich coffee',
#  'low-sodium barbecue sauce',
#  'crawfish',
#  'Ragu Napoletano (Neapolitan Meat Sauce)',
#  'amchur',
#  'hearts of palm',
#  'lobster',
#  'tri-tip roast',
#  'gumbo file',
#  'salmon steak']

# %%
dictionary_list = []

# %%
ingredients_dict_1 = {
    'fat-free cream cheese with chives': ['cream cheese', 'chives'],
    'raisins': ['raisins'],
    'red maraschino cherry': ['cherries'],
    'Baby Bam': ['Baby Bam'],  
    'dried tart cherries': ['dried tart cherries'],
    'crystallized ginger': ['crystallized ginger'],
    'Basic Short-Crust Pastry': ['short-crust pastry'],
    'treacle': ['treacle'],
    'carob powder': ['carob powder'],
    'barley malt syrup': ['barley malt syrup'],
    'Low Carb Barbecue Sauce': ['barbecue sauce'],
    'Date Filling for Hamentaschen': ['date filling'],
    'chestnut puree': ['chestnut puree'],
    'rolled roast beef': ['rolled roast beef'],
    'tempeh': ['tempeh'],
    'orange-pineapple flavored gelatin': ['orange-pineapple gelatin'],
    'White Balsamic Blackberry W/ Lemon Thyme Vinegar': ['blackberry lemon thyme vinegar'],
    'dry milk': ['dry milk'],
    'fresh spearmint': ['spearmint'],
    'lettuce head': ['lettuce'],
    'roasted soybeans': ['roasted soybeans'],
    'dried tomatoes': ['dried tomatoes'],
    'rice powder': ['rice powder'],
    'golden delicious apples': ['Golden Delicious apples'],
    'Achiote Paste': ['Achiote Paste'],
    'sago': ['sago'],
    'Graham Cracker Cheesecake Crust': ['Graham cracker'],  # Adjusted from 'cheesecake crust'
    'fresh dill': ['dill'],
    'southern style hash browns': ['hash browns'],
    'pignolis': ['pignolis']
}
dictionary_list.append(ingredients_dict_1)

# %%
ingredients_dict_2 = {
    'Swedish Meatballs': ['Swedish Meatballs'],
    'Garlic Bread Cro&ucirc;tes': ['Garlic Bread'],
    'nopales': ['nopales'],
    'barbecue sauce': ['barbecue sauce'],
    'red leaf lettuce': ['red leaf lettuce'],
    'low-fat turkey kielbasa': ['low-fat turkey kielbasa'],
    'skim milk': ['skim milk'],
    'white cranberry juice': ['white cranberry juice'],
    'soyabean nuggets': ['soyabean nuggets'],
    'tofu': ['tofu'],
    'iranian rice': ['iranian rice'],
    'sharp American cheese': ['sharp American cheese'],
    'yellow cornmeal': ['yellow cornmeal'],
    'raspberry ice cream': ['raspberry ice cream'],
    'chocolate piece': ['chocolate piece'],
    'boneless salmon fillet': ['boneless salmon fillet'],
    'Curtido (Salvadorean Pickled Coleslaw)': ['Curtido (Salvadorean Pickled Coleslaw)'],
    'blood orange': ['blood orange'],
    'Italian Salad Dressing': ['Italian Salad Dressing'],
    'lettuce greens': ['lettuce greens'],
    'strong rich coffee': ['strong rich coffee'],
    'low-sodium barbecue sauce': ['low-sodium barbecue sauce'],
    'crawfish': ['crawfish'],
    'Ragu Napoletano (Neapolitan Meat Sauce)': ['Ragu Napoletano (Neapolitan Meat Sauce)'],
    'amchur': ['amchur'],
    'hearts of palm': ['hearts of palm'],
    'lobster': ['lobster'],
    'tri-tip roast': ['tri-tip roast'],
    'gumbo file': ['gumbo file'],
    'salmon steak': ['salmon steak']
}
dictionary_list.append(ingredients_dict_2)

# %%
ingredients_dict_3 = {
    'capsicums': ['capsicums'],
    'ice cream sandwiches': ['ice cream sandwiches'],
    'morton lite salt': ['morton lite salt'],
    'low-fat ricotta': ['low-fat ricotta'],
    'Roasted Garlic': ['Roasted Garlic'],
    'tri-tip steak': ['tri-tip steak'],
    'Pecan Praline Topping': ['Pecan Praline Topping'],
    'Chipotle Compound Butter': ['Chipotle Compound Butter'],
    'streaky bacon': ['streaky bacon'],
    'hing': ['hing'],
    'quick-cooking brown rice': ['quick-cooking brown rice'],
    'Vegan Parmesan': ['Vegan Parmesan'],
    'vanilla bean paste': ['vanilla bean paste'],
    'frozen corn': ['frozen corn'],
    'mint sauce': ['mint sauce'],
    'leg of lamb': ['leg of lamb'],
    'light mozzarella cheese': ['light mozzarella cheese'],
    'puff pastry shells': ['puff pastry shells'],
    'Olive Salad Mix': ['Olive Salad Mix'],
    'sweet cherries': ['sweet cherries'],
    'wild ducks': ['wild ducks'],
    'turkey broth': ['turkey broth'],
    'lamb gravy': ['lamb gravy'],
    "Mom's Hummus": ["Mom's Hummus"],
    'Pepperidge Farm stuffing': ['Pepperidge Farm stuffing'],
    'soho lychee liqueur': ['soho lychee liqueur'],
    'honey-wheat bagel': ['honey-wheat bagel'],
    'whole leaf oregano': ['whole leaf oregano'],
    'boneless beef chuck shoulder pot roast': ['boneless beef chuck shoulder pot roast'],
    'spiced apple cider': ['spiced apple cider']
}
dictionary_list.append(ingredients_dict_3)

# %%
ingredients_dict_4 = {
    'unsweetened pineapple chunks': ['unsweetened pineapple chunks'],
    'italian tomatoes with juice': ['italian tomatoes with juice'],
    'Quaker quick barley': ['Quaker quick barley'],
    'Japanese roasted nori': ['Japanese roasted nori'],
    'plain cornmeal': ['plain cornmeal'],
    'bagel': ['bagel'],
    'steelhead trout': ['steelhead trout'],
    'grapefruit peel': ['grapefruit peel'],
    'buttermilk': ['buttermilk'],
    'Pate Brisee': ['Pate Brisee'],
    'low-sodium mozzarella cheese': ['low-sodium mozzarella cheese'],
    'barley groats': ['barley groats'],
    'Enchilada Sauce': ['Enchilada Sauce'],
    'garlic and cheese flavored croutons': ['garlic and cheese flavored croutons'],
    'blueberry ice cream': ['blueberry ice cream'],
    'top round roast': ['top round roast'],
    'Hunts tomato sauce': ['Hunts tomato sauce'],
    'gum arabic': ['gum arabic'],
    'Best Ever Homemade Mayonnaise': ['Best Ever Homemade Mayonnaise'],
    'rice paper sheet': ['rice paper sheet'],
    'ReaLemon juice': ['ReaLemon juice'],
    'red chile': ['red chile'],
    'country-style boneless pork ribs': ['country-style boneless pork ribs'],
    'soy ice cream': ['soy ice cream'],
    'pickle juice': ['pickle juice'],
    'Crumb Cake Mix': ['Crumb Cake Mix'],
    'green onions with tops': ['green onions with tops'],
    'herb seasoned stuffing mix': ['herb seasoned stuffing mix'],
    'ham slices': ['ham slices'],
    'chat masala': ['chat masala']
}
dictionary_list.append(ingredients_dict_4)

# %%
ingredients_dict_5 = {
    'sugar-free peach gelatin mix': ['sugar-free peach gelatin mix'],
    'watermelon gelatin': ['watermelon gelatin'],
    'Robin Hood all-purpose flour': ['all-purpose flour'],
    'Pico De Gallo': ['Pico De Gallo'],
    'yucca root': ['yucca root'],
    'barbecued pork': ['barbecued pork'],
    'stone-ground white cornmeal': ['stone-ground white cornmeal'],
    'roasted smoked skinless turkey': ['roasted smoked skinless turkey'],
    'frozen sweet peppers': ['frozen sweet peppers'],
    'fat-free chicken broth': ['fat-free chicken broth'],
    'black peppercorns': ['black peppercorns'],
    'red paprika': ['red paprika'],
    'fresh lima beans': ['fresh lima beans'],
    'green cherries': ['green cherries'],
    'black rice': ['black rice'],
    'garlic bagel': ['garlic bagel'],
    'solid pack pumpkin': ['solid pack pumpkin'],
    'Maple Vinaigrette': ['Maple Vinaigrette'],
    'fresh garlic': ['fresh garlic'],
    'Nido milk': ['Nido milk'],
    'vegetarian chicken broth': ['vegetarian chicken broth'],
    'Southern Fluffy Frosting': ['Southern Fluffy Frosting'],
    'Jell-O pudding mix': ['Jell-O pudding mix'],
    'dill pickle slices': ['dill pickle slices'],
    'Robin Hood oats': ['oats'],
    'shoe peg corn': ['shoe peg corn'],
    'tomato paste': ['tomato paste'],
    'pistachio oil': ['pistachio oil'],
    'Dukkah': ['Dukkah'],
    'Old English Spiced and Fruited Sugar for Apple Pies Etc!': ['Old English Spiced and Fruited Sugar']
}
dictionary_list.append(ingredients_dict_5)

# %%
ingredients_dict_6 = {
    'dried cayenne peppers': ['dried cayenne peppers'],
    'moist coconut': ['moist coconut'],
    'tomato sauce with onion': ['tomato sauce with onion'],
    'marzipan paste': ['marzipan paste'],
    'soy lecithin': ['soy lecithin'],
    'crushed tomatoes': ['crushed tomatoes'],
    'worcestershire powder': ['worcestershire powder'],
    'whole wheat baguette': ['whole wheat baguette'],
    'ground oregano': ['ground oregano'],
    "Kittencal's Garlic Croutons": ["Kittencal's Garlic Croutons"],
    'lamb rib chops': ['lamb rib chops'],
    'Tomatillo Sauce': ['Tomatillo Sauce'],
    'karela': ['karela'],
    'strawberry cream cheese': ['strawberry cream cheese'],
    'Japanese sake': ['Japanese sake'],
    'celery root': ['celery root'],
    'fava bean pods': ['fava bean pods'],
    'litchis': ['litchis'],
    'Soft Silk flour': ['Soft Silk flour'],
    'diced tomatoes with sweet onions': ['diced tomatoes with sweet onions'],
    'instant decaffeinated coffee': ['instant decaffeinated coffee'],
    'white wine': ['white wine'],
    'Grey Poupon Dijon Mustard': ['Grey Poupon Dijon Mustard'],
    'amaretto di saronno liqueur': ['amaretto di saronno liqueur'],
    'cracked bulgur wheat': ['cracked bulgur wheat'],
    'green cardamom powder': ['green cardamom powder'],
    'canned anchovy fillets': ['canned anchovy fillets'],
    'Starkist lemon and cracked pepper tuna fillets': ['Starkist lemon and cracked pepper tuna fillets'],
    'chicken liver': ['chicken liver'],
    'garam masala': ['garam masala']
}
dictionary_list.append(ingredients_dict_6)

# %%
ingredients_dict_7 = {
    'no-salt-added pinto beans': ['no-salt-added pinto beans'],
    'blue-eye cod fillet': ['blue-eye cod fillet'],
    'vanilla-flavored soymilk': ['vanilla-flavored soymilk'],
    'basil leaves': ['basil leaves'],
    'Copycat Cinnabon Rolls With Icing': ['Copycat Cinnabon Rolls With Icing'],
    'boneless center cut pork loin roast': ['boneless center cut pork loin roast'],
    'Chocolate Syrup': ['Chocolate Syrup'],
    'Stilton cheese': ['Stilton cheese'],
    'chipotle peppers': ['chipotle peppers'],
    'hot chicken broth': ['hot chicken broth'],
    'Hunts Ready Tomato Sauces Chunky Special': ['Hunts Ready Tomato Sauces Chunky Special'],
    'pickled sweet peppers': ['pickled sweet peppers'],
    "Jo Mama's World Famous Spaghetti": ["Jo Mama's World Famous Spaghetti"],
    'coconut milk powder': ['coconut milk powder'],
    'Mexican Red Chile Sauce': ['Mexican Red Chile Sauce'],
    'diced tomatoes with balsamic vinegar basil and oil': ['diced tomatoes with balsamic vinegar basil and oil'],
    'sauerkraut': ['sauerkraut'],
    'English mustard powder': ['English mustard powder'],
    'Italian-style stewed tomatoes': ['Italian-style stewed tomatoes'],
    'Rays of Sunshine - Homemade Candied Orange Peel': ['Rays of Sunshine - Homemade Candied Orange Peel'],
    'fresh rosemary needles': ['fresh rosemary needles'],
    'plain white flour': ['plain white flour'],
    'Italian Dressing Seasoning Dry Mix': ['Italian Dressing Seasoning Dry Mix'],
    'imported bittersweet chocolate': ['imported bittersweet chocolate'],
    'Rotel tomatoes & chilies': ['Rotel tomatoes & chilies'],
    'yoghurt': ['yoghurt'],
    'mozzarella-cheddar blend cheese': ['mozzarella-cheddar blend cheese'],
    'smoked gruyere cheese': ['smoked gruyere cheese'],
    'frozen puff pastry shells': ['frozen puff pastry shells'],
    'other sweet onion': ['other sweet onion']
}
dictionary_list.append(ingredients_dict_7)

# %%
ingredients_dict_8 = {
    "Kittencal's No-Cook Pizza Sauce or Marinara Dipping Sauce": ["Kittencal's No-Cook Pizza Sauce or Marinara Dipping Sauce"],
    'Major Grey chutney': ['Major Grey chutney'],
    'white grapes': ['white grapes'],
    'unsweetened flaked coconut': ['unsweetened flaked coconut'],
    'thyme': ['thyme'],
    'anchovy paste': ['anchovy paste'],
    'hard alcoholic cider': ['hard alcoholic cider'],
    'phyllo pastry sheets': ['phyllo pastry sheets'],
    'quahogs': ['quahogs'],
    'quince paste': ['quince paste'],
    'yellow fin potatoes': ['yellow fin potatoes'],
    'Ener-G Egg Substitute': ['Ener-G Egg Substitute'],
    'salt': ['salt'],
    'salmon salad': ['salmon salad'],
    'Elevated Challah': ['Elevated Challah'],
    '2% buttermilk': ['2% buttermilk'],
    'pitted dates': ['pitted dates'],
    'chestnut puree': ['chestnut puree'],
    'Belgian endive': ['Belgian endive'],
    'dry cider': ['dry cider'],
    'chocolate instant pudding': ['chocolate instant pudding'],
    'solid white tuna': ['solid white tuna'],
    'boneless duck breasts': ['boneless duck breasts'],
    'Mashed Potatoes With Jarlsberg Cheese': ['Mashed Potatoes With Jarlsberg Cheese'],
    'clear broth': ['clear broth'],
    'red gelatin': ['red gelatin'],
    'unsifted flour': ['unsifted flour'],
    'coffee-infused vodka': ['coffee-infused vodka'],
    'Tilsit cheese': ['Tilsit cheese'],
    'nectarines': ['nectarines']
}
dictionary_list.append(ingredients_dict_8)

# %%
ingredients_dict_9 = {
    'portabella mushrooms': ['portabella mushrooms'],
    'vegan egg substitute': ['vegan egg substitute'],
    'Mucho Gusto Taco Seasoning Mix': ['Mucho Gusto Taco Seasoning Mix'],
    'boneless beef rump roast': ['boneless beef rump roast'],
    'red onions': ['red onions'],
    'scallion tops': ['scallion tops'],
    'pork escalopes': ['pork escalopes'],
    'white Creme de Cacao': ['white Creme de Cacao'],
    'Nestle chocolate milk': ['Nestle chocolate milk'],
    'ham shanks': ['ham shanks'],
    'Basic Short-Crust Pastry': ['Basic Short-Crust Pastry'],
    'tea bag': ['tea bag'],
    'Urad Dal': ['Urad Dal'],
    'adobo seasoning': ['adobo seasoning'],
    'white meat chicken': ['white meat chicken'],
    'green bananas': ['green bananas'],
    'sausages': ['sausages'],
    'sweet unsalted butter': ['sweet unsalted butter'],
    'ricotta salata': ['ricotta salata'],
    'pineapple sage': ['pineapple sage'],
    'tandoori spice mix': ['tandoori spice mix'],
    'ovolini': ['ovolini'],
    'Chinese radishes': ['Chinese radishes'],
    'vegetarian meatballs': ['vegetarian meatballs'],
    'boneless lamb roast': ['boneless lamb roast'],
    'pistachio ice cream': ['pistachio ice cream'],
    'Heavenly Hummus': ['Heavenly Hummus'],
    'lean lamb fillets': ['lean lamb fillets'],
    'black sesame seeds': ['black sesame seeds'],
    'prune baby food': ['prune baby food']
}
dictionary_list.append(ingredients_dict_9)

# %%
list_index += 1
print(f"Batch: {list_index+1},      Range:{30*list_index} - {30*(list_index+1)}")
ingredients_list[30*list_index:30*(list_index+1)]
# Out:
# Batch: 9,      Range:240 - 270
# ['portabella mushrooms',
#  'vegan egg substitute',
#  'Mucho Gusto Taco Seasoning Mix',
#  'boneless beef rump roast',
#  'red onions',
#  'scallion tops',
#  'pork escalopes',
#  'white Creme de Cacao',
#  'Nestle chocolate milk',
#  'ham shanks',
#  'Basic Short-Crust Pastry',
#  'tea bag',
#  'Urad Dal',
#  'adobo seasoning',
#  'white meat chicken',
#  'green bananas',
#  'sausages',
#  'sweet unsalted butter',
#  'ricotta salata',
#  'pineapple sage',
#  'tandoori spice mix',
#  'ovolini',
#  'Chinese radishes',
#  'vegetarian meatballs',
#  'boneless lamb roast',
#  'pistachio ice cream',
#  'Heavenly Hummus',
#  'lean lamb fillets',
#  'black sesame seeds',
#  'prune baby food']
