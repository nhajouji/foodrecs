# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
cooktimes = pd.read_pickle('../data/rectimes.pk')

# %%
cooktimes.head()
# Out:
#          CookTime PrepTime TotalTime
# RecipeId
# 38          PT24H    PT45M  PT24H45M
# 39          PT25M     PT4H   PT4H25M
# 40           PT5M    PT30M     PT35M
# 41          PT20M    PT24H  PT24H20M
# 42          PT30M    PT20M     PT50M

# %%
cooktimes=cooktimes.fillna('0S')

# %%
def clean_cooktime(cooktime:str)->float:
    if type(cooktime)!=str:
        return cooktime
    elif cooktime[-1]=='S':
        return 0
    time = 0
    digits = [str(n) for n in range(10)]
    while cooktime[0] not in digits:
        cooktime = cooktime[1:]
    while len(cooktime)>0:
        i = 0
        while cooktime[i] in digits:
            i+=1
        tn = int(cooktime[:i])
        if cooktime[i] == 'H':
            time+=60*tn
            cooktime = cooktime[i+1:]
        else:
            time+=tn
            return time
    return time

# %%
cooktimes['CookTimeClean']=[clean_cooktime(s) for s in cooktimes.CookTime]
cooktimes['PrepTimeClean']=[clean_cooktime(s) for s in cooktimes.PrepTime]
cooktimes['TotalTimeClean']=[clean_cooktime(s) for s in cooktimes.TotalTime]

# %%
cooktimes
# Out:
#          CookTime PrepTime TotalTime  CookTimeClean  PrepTimeClean  \
# RecipeId
# 38          PT24H    PT45M  PT24H45M           1440             45
# 39          PT25M     PT4H   PT4H25M             25            240
# 40           PT5M    PT30M     PT35M              5             30
# 41          PT20M    PT24H  PT24H20M             20           1440
# 42          PT30M    PT20M     PT50M             30             20
# ...           ...      ...       ...            ...            ...
# 541379      PT35M     PT1H   PT1H35M             35             60
# 541380       PT3H    PT30M   PT3H30M            180             30
# 541381       PT3H     PT1H      PT4H            180             60
# 541382         0S    PT15M     PT15M              0             15
# 541383      PT25M    PT15M     PT40M             25             15
#
#           TotalTimeClean
# RecipeId
# 38                  1485
# 39                   265
# 40                    35
# 41                  1460
# ...

# %%
cooktimes.loc[cooktimes.TotalTimeClean-cooktimes.CookTimeClean-cooktimes.PrepTimeClean==0][['PrepTimeClean','CookTimeClean','TotalTimeClean']].to_parquet('../data/clean_columns/cooktimesclean.parquet')

# %%
set([type(s) for s in timestrings0])
# Out:
# {NoneType, str}
